# %% [markdown]
# # Dataset generation for fine-tuning on Cthulhu rulebook
#
# This notebook generates a dataset that can be used to fine-tune an LLM to answer questions regarding the Cthulhu rule book.
# The notebook takes in input a PDF file contaning the Cthulhu rule book.
# It outputs a dataset of QA pairs derived from the rule book, which can be used to fine-tune the LLM.
#
# The dataset is generated using the [Meta Synthetic Data Kit](https://github.com/meta-llama/synthetic-data-kit/tree/main/synthetic_data_kit). At a high level, we do the following::
#
# - startup a local LLM server using VLLM (we use `unsloth/Llama-3.2-3B-Instruct`)
#
# - put the rule book in `data/pdf`.
# - covert the PDF in the `data/pdf` directory into a text file, stored in the `data/output` directory, using the  Meta Synthetic Data Kit's `ingest` function.
#
# - chunk the text file into smaller files of 2048 tokens (with 64 tokens overlap), which are stored in `data/output`.
#
# - feed each chunk file to the Meta Synthetic Data Kit's `create` function. The function prompts the VLLM to generate 25 QA pairs for each of the chunk files. For each chunk file a corresponding file containing QA pairs is created in  `data/generated`.
#
# - feed each QA pair file to the Meta Synthetic Data Kit's `curate` function. The function prompts the VLLM to retain only QA pairs above a given quality threshold. For each QA pair file a corresponding file containing high-quality QA pairs is created in `data/curated`.
#
# If running on Google Colab, ensure to run with a A100 GPU environment.
#
# \\
# References:
# - [Meta kit page](https://github.com/meta-llama/synthetic-data-kit/blob/main/README.md)
# - [Unsloth collab notebook](https://colab.research.google.com/github/unslothai/notebooks/blob/main/nb/Meta_Synthetic_Data_Llama3_2_(3B).ipynb#scrollTo=2ejIt2xSNKKp)

# %% [markdown]
# ## Install dependencies and cloning github repo
#
# The github repo is used to store the generated dataset

# %%
# %%capture
# !pip install synthetic-data-kit==0.0.3

import os
if "COLAB_" not in "".join(os.environ.keys()):
    # !pip install vllm
else:
    # vLLM requirements - vLLM breaks Colab due to reinstalling numpy
    import re, requests
    # !pip install --no-deps vllm
    # !pip install --no-deps bitsandbytes
    f = requests.get("https://raw.githubusercontent.com/vllm-project/vllm/refs/heads/main/requirements/common.txt").content
    with open("vllm_requirements.txt", "wb") as file:
        file.write(re.sub(rb"(transformers|numpy|xformers)[^\n]{1,}\n", b"", f))
    # !pip install -r vllm_requirements.txt
# Out:
# Requirement already satisfied: synthetic-data-kit==0.0.3 in /usr/local/lib/python3.11/dist-packages (0.0.3)
# Requirement already satisfied: datasets>=2.14.0 in /usr/local/lib/python3.11/dist-packages (from synthetic-data-kit==0.0.3) (2.14.4)
# Requirement already satisfied: pdfminer-six>=20221105 in /usr/local/lib/python3.11/dist-packages (from synthetic-data-kit==0.0.3) (20250506)
# Requirement already satisfied: pydantic>=2.4.0 in /usr/local/lib/python3.11/dist-packages (from synthetic-data-kit==0.0.3) (2.11.4)
# Requirement already satisfied: python-docx>=0.8.11 in /usr/local/lib/python3.11/dist-packages (from synthetic-data-kit==0.0.3) (1.1.2)
# Requirement already satisfied: python-pptx>=0.6.21 in /usr/local/lib/python3.11/dist-packages (from synthetic-data-kit==0.0.3) (1.0.2)
# Requirement already satisfied: pytube>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from synthetic-data-kit==0.0.3) (15.0.0)
# Requirement already satisfied: pyyaml>=6.0 in /usr/local/lib/python3.11/dist-packages (from synthetic-data-kit==0.0.3) (6.0.2)
# Requirement already satisfied: requests>=2.31.0 in /usr/local/lib/python3.11/dist-packages (from synthetic-data-kit==0.0.3) (2.32.3)
# Requirement already satisfied: rich>=13.4.2 in /usr/local/lib/python3.11/dist-packages (from synthetic-data-kit==0.0.3) (13.9.4)
# Requirement already satisfied: typer>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from synthetic-data-kit==0.0.3) (0.15.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from datasets>=2.14.0->synthetic-data-kit==0.0.3) (2.0.2)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets>=2.14.0->synthetic-data-kit==0.0.3) (18.1.0)
# Requirement already satisfied: dill<0.3.8,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from datasets>=2.14.0->synthetic-data-kit==0.0.3) (0.3.7)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets>=2.14.0->synthetic-data-kit==0.0.3) (2.2.2)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.11/dist-packages (from datasets>=2.14.0->synthetic-data-kit==0.0.3) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/dist-packages (from datasets>=2.14.0->synthetic-data-kit==0.0.3) (3.5.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.11/dist-packages (from datasets>=2.14.0->synthetic-data-kit==0.0.3) (0.70.15)
# Requirement already satisfied: fsspec>=2021.11.1 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]>=2021.11.1->datasets>=2.14.0->synthetic-data-kit==0.0.3) (2025.3.2)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from datasets>=2.14.0->synthetic-data-kit==0.0.3) (3.11.15)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.14.0 in /usr/local/lib/python3.11/dist-packages (from datasets>=2.14.0->synthetic-data-kit==0.0.3) (0.31.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from datasets>=2.14.0->synthetic-data-kit==0.0.3) (24.2)
# Requirement already satisfied: charset-normalizer>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from pdfminer-six>=20221105->synthetic-data-kit==0.0.3) (3.4.2)
# Requirement already satisfied: cryptography>=36.0.0 in /usr/local/lib/python3.11/dist-packages (from pdfminer-six>=20221105->synthetic-data-kit==0.0.3) (43.0.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.4.0->synthetic-data-kit==0.0.3) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.4.0->synthetic-data-kit==0.0.3) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.4.0->synthetic-data-kit==0.0.3) (4.13.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.4.0->synthetic-data-kit==0.0.3) (0.4.0)
# Requirement already satisfied: lxml>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from python-docx>=0.8.11->synthetic-data-kit==0.0.3) (5.4.0)
# Requirement already satisfied: Pillow>=3.3.2 in /usr/local/lib/python3.11/dist-packages (from python-pptx>=0.6.21->synthetic-data-kit==0.0.3) (11.2.1)
# Requirement already satisfied: XlsxWriter>=0.5.7 in /usr/local/lib/python3.11/dist-packages (from python-pptx>=0.6.21->synthetic-data-kit==0.0.3) (3.2.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.31.0->synthetic-data-kit==0.0.3) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.31.0->synthetic-data-kit==0.0.3) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.31.0->synthetic-data-kit==0.0.3) (2025.4.26)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=13.4.2->synthetic-data-kit==0.0.3) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich>=13.4.2->synthetic-data-kit==0.0.3) (2.19.1)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.11/dist-packages (from typer>=0.9.0->synthetic-data-kit==0.0.3) (8.2.0)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from typer>=0.9.0->synthetic-data-kit==0.0.3) (1.5.4)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.11/dist-packages (from cryptography>=36.0.0->pdfminer-six>=20221105->synthetic-data-kit==0.0.3) (1.17.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.14.0->synthetic-data-kit==0.0.3) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.14.0->synthetic-data-kit==0.0.3) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.14.0->synthetic-data-kit==0.0.3) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.14.0->synthetic-data-kit==0.0.3) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.14.0->synthetic-data-kit==0.0.3) (6.4.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.14.0->synthetic-data-kit==0.0.3) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.14.0->synthetic-data-kit==0.0.3) (1.20.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0.0,>=0.14.0->datasets>=2.14.0->synthetic-data-kit==0.0.3) (3.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=13.4.2->synthetic-data-kit==0.0.3) (0.1.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets>=2.14.0->synthetic-data-kit==0.0.3) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets>=2.14.0->synthetic-data-kit==0.0.3) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets>=2.14.0->synthetic-data-kit==0.0.3) (2025.2)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer-six>=20221105->synthetic-data-kit==0.0.3) (2.22)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->datasets>=2.14.0->synthetic-data-kit==0.0.3) (1.17.0)
# Requirement already satisfied: vllm in /usr/local/lib/python3.11/dist-packages (0.8.5.post1)
# Requirement already satisfied: bitsandbytes in /usr/local/lib/python3.11/dist-packages (0.45.5)
# Ignoring importlib_metadata: markers 'python_version < "3.10"' don't match your environment
# Ignoring six: markers 'python_version > "3.11"' don't match your environment
# Ignoring setuptools: markers 'python_version > "3.11"' don't match your environment
# Requirement already satisfied: cachetools in /usr/local/lib/python3.11/dist-packages (from -r vllm_requirements.txt (line 1)) (5.5.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from -r vllm_requirements.txt (line 2)) (5.9.5)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.11/dist-packages (from -r vllm_requirements.txt (line 3)) (0.2.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from -r vllm_requirements.txt (line 4)) (2.0.2)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.11/dist-packages (from -r vllm_requirements.txt (line 5)) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from -r vllm_requirements.txt (line 6)) (4.67.1)
# Requirement already satisfied: blake3 in /usr/local/lib/python3.11/dist-packages (from -r vllm_requirements.txt (line 7)) (1.0.4)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.11/dist-packages (from -r vllm_requirements.txt (line 8)) (9.0.0)
# Requirement already satisfied: huggingface-hub>=0.30.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub[hf_xet]>=0.30.0->-r vllm_requirements.txt (line 9)) (0.31.2)
# Requirement already satisfied: tokenizers>=0.21.1 in /usr/local/lib/python3.11/dist-packages (from -r vllm_requirements.txt (line 10)) (0.21.1)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.11/dist-packages (from -r vllm_requirements.txt (line 11)) (5.29.4)
# Requirement already satisfied: fastapi>=0.115.0 in /usr/local/lib/python3.11/dist-packages (from fastapi[standard]>=0.115.0->-r vllm_requirements.txt (line 12)) (0.115.12)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from -r vllm_requirements.txt (line 13)) (3.11.15)
# Requirement already satisfied: openai>=1.52.0 in /usr/local/lib/python3.11/dist-packages (from -r vllm_requirements.txt (line 14)) (1.78.1)
# Requirement already satisfied: pydantic>=2.9 in /usr/local/lib/python3.11/dist-packages (from -r vllm_requirements.txt (line 15)) (2.11.4)
# Requirement already satisfied: prometheus_client>=0.18.0 in /usr/local/lib/python3.11/dist-packages (from -r vllm_requirements.txt (line 16)) (0.21.1)
# Requirement already satisfied: pillow in /usr/local/lib/python3.11/dist-packages (from -r vllm_requirements.txt (line 17)) (11.2.1)
# Requirement already satisfied: prometheus-fastapi-instrumentator>=7.0.0 in /usr/local/lib/python3.11/dist-packages (from -r vllm_requirements.txt (line 18)) (7.1.0)
# Requirement already satisfied: tiktoken>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from -r vllm_requirements.txt (line 19)) (0.9.0)
# Requirement already satisfied: lm-format-enforcer<0.11,>=0.10.11 in /usr/local/lib/python3.11/dist-packages (from -r vllm_requirements.txt (line 20)) (0.10.11)
# Requirement already satisfied: llguidance<0.8.0,>=0.7.11 in /usr/local/lib/python3.11/dist-packages (from -r vllm_requirements.txt (line 21)) (0.7.20)
# Requirement already satisfied: outlines==0.1.11 in /usr/local/lib/python3.11/dist-packages (from -r vllm_requirements.txt (line 22)) (0.1.11)
# Requirement already satisfied: lark==1.2.2 in /usr/local/lib/python3.11/dist-packages (from -r vllm_requirements.txt (line 23)) (1.2.2)
# Requirement already satisfied: xgrammar==0.1.19 in /usr/local/lib/python3.11/dist-packages (from -r vllm_requirements.txt (line 24)) (0.1.19)
# Requirement already satisfied: typing_extensions>=4.10 in /usr/local/lib/python3.11/dist-packages (from -r vllm_requirements.txt (line 25)) (4.13.2)
# Requirement already satisfied: filelock>=3.16.1 in /usr/local/lib/python3.11/dist-packages (from -r vllm_requirements.txt (line 26)) (3.18.0)
# Requirement already satisfied: partial-json-parser in /usr/local/lib/python3.11/dist-packages (from -r vllm_requirements.txt (line 27)) (0.2.1.1.post5)
# Requirement already satisfied: pyzmq>=25.0.0 in /usr/local/lib/python3.11/dist-packages (from -r vllm_requirements.txt (line 28)) (26.4.0)
# Requirement already satisfied: msgspec in /usr/local/lib/python3.11/dist-packages (from -r vllm_requirements.txt (line 29)) (0.19.0)
# Requirement already satisfied: gguf>=0.13.0 in /usr/local/lib/python3.11/dist-packages (from -r vllm_requirements.txt (line 30)) (0.16.3)
# Requirement already satisfied: mistral_common>=1.5.4 in /usr/local/lib/python3.11/dist-packages (from mistral_common[opencv]>=1.5.4->-r vllm_requirements.txt (line 32)) (1.5.4)
# Requirement already satisfied: opencv-python-headless>=4.11.0 in /usr/local/lib/python3.11/dist-packages (from -r vllm_requirements.txt (line 33)) (4.11.0.86)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from -r vllm_requirements.txt (line 34)) (6.0.2)
# Requirement already satisfied: einops in /usr/local/lib/python3.11/dist-packages (from -r vllm_requirements.txt (line 37)) (0.8.1)
# Requirement already satisfied: compressed-tensors==0.9.4 in /usr/local/lib/python3.11/dist-packages (from -r vllm_requirements.txt (line 38)) (0.9.4)
# Requirement already satisfied: depyf==0.18.0 in /usr/local/lib/python3.11/dist-packages (from -r vllm_requirements.txt (line 39)) (0.18.0)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.11/dist-packages (from -r vllm_requirements.txt (line 40)) (3.1.1)
# Requirement already satisfied: watchfiles in /usr/local/lib/python3.11/dist-packages (from -r vllm_requirements.txt (line 41)) (1.0.5)
# Requirement already satisfied: python-json-logger in /usr/local/lib/python3.11/dist-packages (from -r vllm_requirements.txt (line 42)) (3.3.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from -r vllm_requirements.txt (line 43)) (1.15.3)
# Requirement already satisfied: ninja in /usr/local/lib/python3.11/dist-packages (from -r vllm_requirements.txt (line 44)) (1.11.1.4)
# Requirement already satisfied: opentelemetry-sdk>=1.26.0 in /usr/local/lib/python3.11/dist-packages (from -r vllm_requirements.txt (line 45)) (1.33.1)
# Requirement already satisfied: opentelemetry-api>=1.26.0 in /usr/local/lib/python3.11/dist-packages (from -r vllm_requirements.txt (line 46)) (1.33.1)
# Requirement already satisfied: opentelemetry-exporter-otlp>=1.26.0 in /usr/local/lib/python3.11/dist-packages (from -r vllm_requirements.txt (line 47)) (1.33.1)
# Requirement already satisfied: opentelemetry-semantic-conventions-ai>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from -r vllm_requirements.txt (line 48)) (0.4.9)
# Requirement already satisfied: interegular in /usr/local/lib/python3.11/dist-packages (from outlines==0.1.11->-r vllm_requirements.txt (line 22)) (0.3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from outlines==0.1.11->-r vllm_requirements.txt (line 22)) (3.1.6)
# Requirement already satisfied: nest_asyncio in /usr/local/lib/python3.11/dist-packages (from outlines==0.1.11->-r vllm_requirements.txt (line 22)) (1.6.0)
# Requirement already satisfied: diskcache in /usr/local/lib/python3.11/dist-packages (from outlines==0.1.11->-r vllm_requirements.txt (line 22)) (5.6.3)
# Requirement already satisfied: referencing in /usr/local/lib/python3.11/dist-packages (from outlines==0.1.11->-r vllm_requirements.txt (line 22)) (0.36.2)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.11/dist-packages (from outlines==0.1.11->-r vllm_requirements.txt (line 22)) (4.23.0)
# Requirement already satisfied: pycountry in /usr/local/lib/python3.11/dist-packages (from outlines==0.1.11->-r vllm_requirements.txt (line 22)) (24.6.1)
# Requirement already satisfied: airportsdata in /usr/local/lib/python3.11/dist-packages (from outlines==0.1.11->-r vllm_requirements.txt (line 22)) (20250224)
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (from outlines==0.1.11->-r vllm_requirements.txt (line 22)) (2.6.0+cu124)
# Requirement already satisfied: outlines_core==0.1.26 in /usr/local/lib/python3.11/dist-packages (from outlines==0.1.11->-r vllm_requirements.txt (line 22)) (0.1.26)
# Requirement already satisfied: transformers>=4.38.0 in /usr/local/lib/python3.11/dist-packages (from xgrammar==0.1.19->-r vllm_requirements.txt (line 24)) (4.51.3)
# Requirement already satisfied: triton in /usr/local/lib/python3.11/dist-packages (from xgrammar==0.1.19->-r vllm_requirements.txt (line 24)) (3.2.0)
# Requirement already satisfied: astor in /usr/local/lib/python3.11/dist-packages (from depyf==0.18.0->-r vllm_requirements.txt (line 39)) (0.8.1)
# Requirement already satisfied: dill in /usr/local/lib/python3.11/dist-packages (from depyf==0.18.0->-r vllm_requirements.txt (line 39)) (0.3.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26.0->-r vllm_requirements.txt (line 5)) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26.0->-r vllm_requirements.txt (line 5)) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26.0->-r vllm_requirements.txt (line 5)) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26.0->-r vllm_requirements.txt (line 5)) (2025.4.26)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.30.0->huggingface-hub[hf_xet]>=0.30.0->-r vllm_requirements.txt (line 9)) (2025.3.2)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.30.0->huggingface-hub[hf_xet]>=0.30.0->-r vllm_requirements.txt (line 9)) (24.2)
# Requirement already satisfied: starlette<0.47.0,>=0.40.0 in /usr/local/lib/python3.11/dist-packages (from fastapi>=0.115.0->fastapi[standard]>=0.115.0->-r vllm_requirements.txt (line 12)) (0.46.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->-r vllm_requirements.txt (line 13)) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->-r vllm_requirements.txt (line 13)) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->-r vllm_requirements.txt (line 13)) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->-r vllm_requirements.txt (line 13)) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->-r vllm_requirements.txt (line 13)) (6.4.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->-r vllm_requirements.txt (line 13)) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->-r vllm_requirements.txt (line 13)) (1.20.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from openai>=1.52.0->-r vllm_requirements.txt (line 14)) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from openai>=1.52.0->-r vllm_requirements.txt (line 14)) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from openai>=1.52.0->-r vllm_requirements.txt (line 14)) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from openai>=1.52.0->-r vllm_requirements.txt (line 14)) (0.9.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from openai>=1.52.0->-r vllm_requirements.txt (line 14)) (1.3.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.9->-r vllm_requirements.txt (line 15)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.9->-r vllm_requirements.txt (line 15)) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.9->-r vllm_requirements.txt (line 15)) (0.4.0)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.11/dist-packages (from tiktoken>=0.6.0->-r vllm_requirements.txt (line 19)) (2024.11.6)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.54b1 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-sdk>=1.26.0->-r vllm_requirements.txt (line 45)) (0.54b1)
# Requirement already satisfied: deprecated>=1.2.6 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-api>=1.26.0->-r vllm_requirements.txt (line 46)) (1.2.18)
# Requirement already satisfied: importlib-metadata<8.7.0,>=6.0 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-api>=1.26.0->-r vllm_requirements.txt (line 46)) (8.6.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc==1.33.1 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-exporter-otlp>=1.26.0->-r vllm_requirements.txt (line 47)) (1.33.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-http==1.33.1 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-exporter-otlp>=1.26.0->-r vllm_requirements.txt (line 47)) (1.33.1)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-exporter-otlp-proto-grpc==1.33.1->opentelemetry-exporter-otlp>=1.26.0->-r vllm_requirements.txt (line 47)) (1.70.0)
# Requirement already satisfied: grpcio<2.0.0,>=1.63.2 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-exporter-otlp-proto-grpc==1.33.1->opentelemetry-exporter-otlp>=1.26.0->-r vllm_requirements.txt (line 47)) (1.71.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.33.1 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-exporter-otlp-proto-grpc==1.33.1->opentelemetry-exporter-otlp>=1.26.0->-r vllm_requirements.txt (line 47)) (1.33.1)
# Requirement already satisfied: opentelemetry-proto==1.33.1 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-exporter-otlp-proto-grpc==1.33.1->opentelemetry-exporter-otlp>=1.26.0->-r vllm_requirements.txt (line 47)) (1.33.1)
# Requirement already satisfied: fastapi-cli>=0.0.5 in /usr/local/lib/python3.11/dist-packages (from fastapi-cli[standard]>=0.0.5; extra == "standard"->fastapi[standard]>=0.115.0->-r vllm_requirements.txt (line 12)) (0.0.7)
# Requirement already satisfied: python-multipart>=0.0.18 in /usr/local/lib/python3.11/dist-packages (from fastapi[standard]>=0.115.0->-r vllm_requirements.txt (line 12)) (0.0.20)
# Requirement already satisfied: email-validator>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from fastapi[standard]>=0.115.0->-r vllm_requirements.txt (line 12)) (2.2.0)
# Requirement already satisfied: uvicorn>=0.12.0 in /usr/local/lib/python3.11/dist-packages (from uvicorn[standard]>=0.12.0; extra == "standard"->fastapi[standard]>=0.115.0->-r vllm_requirements.txt (line 12)) (0.34.2)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub[hf_xet]>=0.30.0->-r vllm_requirements.txt (line 9)) (1.1.2)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.11/dist-packages (from deprecated>=1.2.6->opentelemetry-api>=1.26.0->-r vllm_requirements.txt (line 46)) (1.17.2)
# Requirement already satisfied: dnspython>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from email-validator>=2.0.0->fastapi[standard]>=0.115.0->-r vllm_requirements.txt (line 12)) (2.7.0)
# Requirement already satisfied: typer>=0.12.3 in /usr/local/lib/python3.11/dist-packages (from fastapi-cli>=0.0.5->fastapi-cli[standard]>=0.0.5; extra == "standard"->fastapi[standard]>=0.115.0->-r vllm_requirements.txt (line 12)) (0.15.3)
# Requirement already satisfied: rich-toolkit>=0.11.1 in /usr/local/lib/python3.11/dist-packages (from fastapi-cli>=0.0.5->fastapi-cli[standard]>=0.0.5; extra == "standard"->fastapi[standard]>=0.115.0->-r vllm_requirements.txt (line 12)) (0.14.6)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->openai>=1.52.0->-r vllm_requirements.txt (line 14)) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai>=1.52.0->-r vllm_requirements.txt (line 14)) (0.16.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/dist-packages (from importlib-metadata<8.7.0,>=6.0->opentelemetry-api>=1.26.0->-r vllm_requirements.txt (line 46)) (3.21.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->outlines==0.1.11->-r vllm_requirements.txt (line 22)) (3.0.2)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema->outlines==0.1.11->-r vllm_requirements.txt (line 22)) (2025.4.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema->outlines==0.1.11->-r vllm_requirements.txt (line 22)) (0.24.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch->outlines==0.1.11->-r vllm_requirements.txt (line 22)) (3.4.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->outlines==0.1.11->-r vllm_requirements.txt (line 22)) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->outlines==0.1.11->-r vllm_requirements.txt (line 22)) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->outlines==0.1.11->-r vllm_requirements.txt (line 22)) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch->outlines==0.1.11->-r vllm_requirements.txt (line 22)) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch->outlines==0.1.11->-r vllm_requirements.txt (line 22)) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch->outlines==0.1.11->-r vllm_requirements.txt (line 22)) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch->outlines==0.1.11->-r vllm_requirements.txt (line 22)) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch->outlines==0.1.11->-r vllm_requirements.txt (line 22)) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch->outlines==0.1.11->-r vllm_requirements.txt (line 22)) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch->outlines==0.1.11->-r vllm_requirements.txt (line 22)) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch->outlines==0.1.11->-r vllm_requirements.txt (line 22)) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->outlines==0.1.11->-r vllm_requirements.txt (line 22)) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->outlines==0.1.11->-r vllm_requirements.txt (line 22)) (12.4.127)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch->outlines==0.1.11->-r vllm_requirements.txt (line 22)) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch->outlines==0.1.11->-r vllm_requirements.txt (line 22)) (1.3.0)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.38.0->xgrammar==0.1.19->-r vllm_requirements.txt (line 24)) (0.5.3)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.11/dist-packages (from uvicorn>=0.12.0->uvicorn[standard]>=0.12.0; extra == "standard"->fastapi[standard]>=0.115.0->-r vllm_requirements.txt (line 12)) (8.2.0)
# Requirement already satisfied: httptools>=0.6.3 in /usr/local/lib/python3.11/dist-packages (from uvicorn[standard]>=0.12.0; extra == "standard"->fastapi[standard]>=0.115.0->-r vllm_requirements.txt (line 12)) (0.6.4)
# Requirement already satisfied: python-dotenv>=0.13 in /usr/local/lib/python3.11/dist-packages (from uvicorn[standard]>=0.12.0; extra == "standard"->fastapi[standard]>=0.115.0->-r vllm_requirements.txt (line 12)) (1.1.0)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in /usr/local/lib/python3.11/dist-packages (from uvicorn[standard]>=0.12.0; extra == "standard"->fastapi[standard]>=0.115.0->-r vllm_requirements.txt (line 12)) (0.21.0)
# Requirement already satisfied: websockets>=10.4 in /usr/local/lib/python3.11/dist-packages (from uvicorn[standard]>=0.12.0; extra == "standard"->fastapi[standard]>=0.115.0->-r vllm_requirements.txt (line 12)) (15.0.1)
# Requirement already satisfied: rich>=13.7.1 in /usr/local/lib/python3.11/dist-packages (from rich-toolkit>=0.11.1->fastapi-cli>=0.0.5->fastapi-cli[standard]>=0.0.5; extra == "standard"->fastapi[standard]>=0.115.0->-r vllm_requirements.txt (line 12)) (13.9.4)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from typer>=0.12.3->fastapi-cli>=0.0.5->fastapi-cli[standard]>=0.0.5; extra == "standard"->fastapi[standard]>=0.115.0->-r vllm_requirements.txt (line 12)) (1.5.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=13.7.1->rich-toolkit>=0.11.1->fastapi-cli>=0.0.5->fastapi-cli[standard]>=0.0.5; extra == "standard"->fastapi[standard]>=0.115.0->-r vllm_requirements.txt (line 12)) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich>=13.7.1->rich-toolkit>=0.11.1->fastapi-cli>=0.0.5->fastapi-cli[standard]>=0.0.5; extra == "standard"->fastapi[standard]>=0.115.0->-r vllm_requirements.txt (line 12)) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=13.7.1->rich-toolkit>=0.11.1->fastapi-cli>=0.0.5->fastapi-cli[standard]>=0.0.5; extra == "standard"->fastapi[standard]>=0.115.0->-r vllm_requirements.txt (line 12)) (0.1.2)

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-7-91874b305a32> in <cell line: 0>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive/')
#
# /usr/local/lib/python3.11/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      98 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      99   """Mount your Google Drive at the specified mountpoint path."""
# --> 100   return _mount(
#     101       mountpoint,
#     102       force_remount=force_remount,
#
# /usr/local/lib/python3.11/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     135   )
#     136   if ephemeral:
# --> 137     _message.blocking_request(
#     138         'request_auth',
#     139         request={'authType': 'dfs_ephemeral'},
#
# /usr/local/lib/python3.11/dist-packages/google/colab/_message.py in blocking_request(request_type, request, timeout_sec, parent)
#     174       request_type, request, parent=parent, expect_reply=True
#     175   )
# --> 176   return read_reply_from_input(request_id, timeout_sec)
#
# /usr/local/lib/python3.11/dist-packages/google/colab/_message.py in read_reply_from_input(message_id, timeout_sec)
#     101     ):
#     102       if 'error' in reply:
# --> 103         raise MessageError(reply['error'])
#     104       return reply.get('data', None)
#     105
#
# MessageError: Error: credential propagation was unsuccessful

# %%
# CLONING REPO CONTAINING INPUT DATA
#
# this is also the repo where we will store intermediate data

! mkdir -p /root/.ssh
with open("/root/.ssh/id_rsa", mode="w") as fp:
    fp.write("""-----BEGIN OPENSSH PRIVATE KEY-----

-----END OPENSSH PRIVATE KEY-----

""")

# <COPY FROM LOCAL DISK AT: ~/dev/llm_cthulhu_fine_tuning/keys>
! ssh-keyscan -t rsa github.com >> ~/.ssh/known_hosts
! chmod go-rwx /root/.ssh/id_rsa
! git clone git@github.com:ellolo/cthulhu_fine_tuning.git
# Out:
# # github.com:22 SSH-2.0-4c545346
# Cloning into 'cthulhu_fine_tuning'...
# remote: Enumerating objects: 1757, done.
# remote: Counting objects: 100% (1749/1749), done.
# remote: Compressing objects: 100% (1183/1183), done.
# remote: Total 1757 (delta 574), reused 1739 (delta 564), pack-reused 8 (from 1)
# Receiving objects: 100% (1757/1757), 70.37 MiB | 8.57 MiB/s, done.
# Resolving deltas: 100% (574/574), done.

# %%
# %cd /content/cthulhu_fine_tuning
! mkdir -p data/{pdf,html,youtube,docx,ppt,txt,output,generated,cleaned,final}
# Out:
# /content/cthulhu_fine_tuning

# %% [markdown]
# # Start serving LLM model

# %%
# START VLLM
# if in Google Collab, use A100 GPU
# https://docs.vllm.ai/en/stable/serving/openai_compatible_server.html#cli-reference
#
# It takes some time to get the VLLM server up.
# To check if it is ready, run the next cell or check the log file vll_logs.out
# below

#! NCCL_P2P_DISABLE=1 VLLM_LOGGING_LEVEL=DEBUG CUDA_LAUNCH_BLOCKING=1 NCCL_DEBUG=TRACE VLLM_TRACE_FUNCTION=1 vllm serve unsloth/Llama-3.2-3B-Instruct --port 8000 --gpu-memory-utilization 0.8 --max_model_len 2048
# %cd /content/cthulhu_fine_tuning/
! VLLM_LOGGING_LEVEL=DEBUG vllm serve \
    unsloth/Llama-3.2-3B-Instruct \
    --port 8000 \
    --gpu-memory-utilization 0.8 \
    --max_model_len 2048 \
    --quantization bitsandbytes > vllm_logs.out 2> vllm_logs.err &
# Out:
# /content/cthulhu_fine_tuning

# %%
# check if/when VLLM server is up

# !synthetic-data-kit system-check
# Out:
#  VLLM server is running at http://localhost:8000/v1
# Available models: {'object': 'list', 'data': [{'id':
# 'unsloth/Llama-3.2-3B-Instruct', 'object': 'model', 'created': 1747653574,
# 'owned_by': 'vllm', 'root': 'unsloth/Llama-3.2-3B-Instruct', 'parent': None,
# 'max_model_len': 2048, 'permission': [{'id':
# 'modelperm-83eb9084ff3846f88471e28219f211a6', 'object': 'model_permission',
# 'created': 1747653574, 'allow_create_engine': False, 'allow_sampling': True,
# 'allow_logprobs': True, 'allow_search_indices': False, 'allow_view': True,
# 'allow_fine_tuning': False, 'organization': '*', 'group': None, 'is_blocking':
# False}]}]}
# ⠋ Checking VLLM server at http://localhost:8000/v1...

# %% [markdown]
# ## Chunk file

# %%
# Function of chunk file into smaller files
# Adapted from:
# https://github.com/unslothai/unsloth/blob/main/unsloth/dataprep/synthetic.py

from transformers import AutoConfig, AutoTokenizer
import numpy as np

def chunk_data(
    filename: str,
    tokenizer,
    max_seq_length: int = 2048,
    max_generation_tokens: int = 512,
    overlap: int = 64,
    ):
        # Chunks data by max tokens and generation length
        assert(filename is not None)
        assert(os.path.exists(filename))

        with open(filename, "r") as f: text = f.read()

        max_tokens = max_seq_length - max_generation_tokens*2 - 128 # -128 to reduce errors
        if max_tokens <= 5:
            raise RuntimeError("Generation length is way too long!")
        input_ids = tokenizer(text, add_special_tokens = False).input_ids

        # Get left and right boundaries
        length = len(input_ids)
        n_chunks = int(np.ceil(length / (max_tokens - overlap)))
        boundaries = np.ceil(np.linspace(0, length - overlap, n_chunks)).astype(int)
        boundaries = np.stack((boundaries[:-1], (boundaries + overlap)[1:])).T
        boundaries = np.minimum(boundaries, length).tolist()

        # Get extension of filename like .txt
        filename, extension = os.path.splitext(filename)
        if filename.endswith("/"): filename = filename[:-1]

        all_filenames = []
        for i, (left, right) in enumerate(boundaries):
            chunked_text = tokenizer.decode(input_ids[left : right])
            new_filename = f"{filename}_{i}{extension}"
            all_filenames.append(new_filename)
            with open(new_filename, "w") as f: f.write(chunked_text)
        pass
        return all_filenames

# %%
# EXTRACT PDF INTO TXT
#
# parse pdf and store into text file into data/output directory.
# %cd /content/cthulhu_fine_tuning/
print("Extracting pdf...")
# !synthetic-data-kit ingest data/pdf/cthulhu.pdf
# Out:
# /content/cthulhu_fine_tuning
# Extracting pdf...
# ⠦ Processing data/pdf/cthulhu.pdf...
#  Text successfully extracted to data/output/cthulhu.txt

# %%
# SPLIT TXT INTO CHUNK FILES
#
# Tokenize the document using appropriate tokenizer, splits the full token
# sequence into chunks of length chunk_size tokens, and stores the corresponding
# textual chunks into output directory

max_seq_length = 2048
max_generation_tokens = 512
overlap = 64
model_name = "unsloth/Llama-3.2-3B-Instruct"
tokenizer = AutoTokenizer.from_pretrained(model_name)

print("Tokenizing and chunking...")
filenames = chunk_data(
    "data/output/cthulhu.txt",
    tokenizer,
    max_seq_length=max_seq_length,
    max_generation_tokens=max_generation_tokens,
    overlap=overlap,
    )
print(len(filenames), filenames[:3])
# Out:
# Tokenizing and chunking...
# 560 ['data/output/cthulhu_0.txt', 'data/output/cthulhu_1.txt', 'data/output/cthulhu_2.txt']

# %% [markdown]
# ## Generate QA pairs

# %%
# GENERATE QA PAIRS
#
# The output is sotired into data/generated
#
# Parameters:
#  --num-pairs: number of generations per chunk (e.g. num of QA pairs)
#  --type:      type of generation. Can be:
#               qa: QA pairs
#               cot: chain of thoughts
#
# QA are generated as follows, for each chunk:
#   - ask llm to generate a 3-5 sentence summary of the chunk, using the prompt
#     stored in the config file: https://github.com/meta-llama/synthetic-data-kit/blob/main/configs/config.yaml)
#     temperature for this task is set to 0.1
#   - sub-chunks each chunk into smaller chunks
#   - ask to generate 25 QA pairs for each chunk. Specifically, for each
#     sub-chunk: ask llm to generate 25/num_subchunks QA pairs using QA prompt
#     stored in the config file: https://github.com/meta-llama/synthetic-data-kit/blob/main/configs/config.yaml)
#
# Look here for more details:
# https://github.com/meta-llama/synthetic-data-kit/blob/main/synthetic_data_kit/generators/qa_generator.py
import glob
import os

out_dir = "data/output"
gen_dir = "data/generated"

# get list of files for which QA pairs have been already generated
generated_files = glob.glob(f"{gen_dir}/*pairs.json")
if generated_files:
  print(generated_files)
  base_name = generated_files[0].split("/")[-1]
  base_name = "_".join(base_name.split("_")[0:-3])
  completed_files = [
      f"{out_dir}/{base_name}_{fname.split('_')[-3]}.txt" for fname in generated_files
      ]
  print(f"QA pairs already generated for {len(completed_files)} files")

  # get list of output files
  filenames = sorted(glob.glob(f"{out_dir}/*_[0-9]*.txt"), key=os.path.getmtime)
  filenames_to_do = list(set(filenames) - set(completed_files))
  print(f"Need to generate for {len(filenames_to_do)} files")
else:
  filenames_to_do = filenames
  print(f"Need to generate for {len(filenames_to_do)} files")
# Out:
# ['data/generated/cthulhu_14_qa_pairs.json', 'data/generated/cthulhu_251_qa_pairs.json', 'data/generated/cthulhu_39_qa_pairs.json', 'data/generated/cthulhu_451_qa_pairs.json', 'data/generated/cthulhu_24_qa_pairs.json', 'data/generated/cthulhu_1_qa_pairs.json', 'data/generated/cthulhu_492_qa_pairs.json', 'data/generated/cthulhu_28_qa_pairs.json', 'data/generated/cthulhu_29_qa_pairs.json', 'data/generated/cthulhu_391_qa_pairs.json', 'data/generated/cthulhu_13_qa_pairs.json', 'data/generated/cthulhu_0_qa_pairs.json', 'data/generated/cthulhu_255_qa_pairs.json', 'data/generated/cthulhu_17_qa_pairs.json', 'data/generated/cthulhu_279_qa_pairs.json', 'data/generated/cthulhu_457_qa_pairs.json', 'data/generated/cthulhu_90_qa_pairs.json', 'data/generated/cthulhu_16_qa_pairs.json', 'data/generated/cthulhu_269_qa_pairs.json', 'data/generated/cthulhu_4_qa_pairs.json', 'data/generated/cthulhu_19_qa_pairs.json', 'data/generated/cthulhu_6_qa_pairs.json', 'data/generated/cthulhu_26_qa_pairs.json', 'data/generated/cthulhu_190_qa_pairs.json', 'data/generated/cthulhu_395_qa_pairs.json', 'data/generated/cthulhu_68_qa_pairs.json', 'data/generated/cthulhu_21_qa_pairs.json', 'data/generated/cthulhu_379_qa_pairs.json', 'data/generated/cthulhu_3_qa_pairs.json', 'data/generated/cthulhu_22_qa_pairs.json', 'data/generated/cthulhu_314_qa_pairs.json', 'data/generated/cthulhu_160_qa_pairs.json', 'data/generated/cthulhu_8_qa_pairs.json', 'data/generated/cthulhu_15_qa_pairs.json', 'data/generated/cthulhu_12_qa_pairs.json', 'data/generated/cthulhu_10_qa_pairs.json', 'data/generated/cthulhu_18_qa_pairs.json', 'data/generated/cthulhu_99_qa_pairs.json', 'data/generated/cthulhu_25_qa_pairs.json', 'data/generated/cthulhu_44_qa_pairs.json', 'data/generated/cthulhu_23_qa_pairs.json', 'data/generated/cthulhu_5_qa_pairs.json', 'data/generated/cthulhu_9_qa_pairs.json', 'data/generated/cthulhu_27_qa_pairs.json', 'data/generated/cthulhu_2_qa_pairs.json', 'data/generated/cthulhu_11_qa_pairs.json', 'data/generated/cthulhu_20_qa_pairs.json', 'data/generated/cthulhu_7_qa_pairs.json', 'data/generated/cthulhu_266_qa_pairs.json']
# QA pairs already generated for 49 files
# Need to generate for 511 files

# %%
import time
i = 0
for fname in filenames_to_do:
    print(f"Doing {i+1} of remaining {len(filenames_to_do)} files")
    # !synthetic-data-kit \
        -c synthetic_data_kit_config.yaml \
        create {fname} \
        --num-pairs 25 \
        --type "qa"
    time.sleep(5) # Sleep some time to leave some room for processing
    i += 1
# Out:
# Doing 1 of remaining 511 files
# Processing 3 chunks to generate QA pairs...
# Batch processing complete.
# Generated 24 QA pairs total
# Saving result to data/generated/cthulhu_484_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_484_qa_pairs.json
# ⠦ Generating qa content from data/output/cthulhu_484.txt...
#  Content saved to data/generated/cthulhu_484_qa_pairs.json
# Doing 2 of remaining 511 files
# Processing 6 chunks to generate QA pairs...
# Batch processing complete.
# Generated 22 QA pairs total
# Saving result to data/generated/cthulhu_58_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_58_qa_pairs.json
# ⠧ Generating qa content from data/output/cthulhu_58.txt...
#  Content saved to data/generated/cthulhu_58_qa_pairs.json
# Doing 3 of remaining 511 files
# Processing 6 chunks to generate QA pairs...
# Batch processing complete.
# Generated 22 QA pairs total
# Saving result to data/generated/cthulhu_416_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_416_qa_pairs.json
# ⠦ Generating qa content from data/output/cthulhu_416.txt...
#  Content saved to data/generated/cthulhu_416_qa_pairs.json
# Doing 4 of remaining 511 files
# Processing 6 chunks to generate QA pairs...
# Batch processing complete.
# Generated 20 QA pairs total
# Saving result to data/generated/cthulhu_95_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_95_qa_pairs.json
# ⠋ Generating qa content from data/output/cthulhu_95.txt...
#  Content saved to data/generated/cthulhu_95_qa_pairs.json
# Doing 5 of remaining 511 files
# Processing 2 chunks to generate QA pairs...
# Batch processing complete.
# Generated 33 QA pairs total
# Saving result to data/generated/cthulhu_536_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_536_qa_pairs.json
# ⠋ Generating qa content from data/output/cthulhu_536.txt...
#  Content saved to data/generated/cthulhu_536_qa_pairs.json
# Doing 6 of remaining 511 files
# Processing 6 chunks to generate QA pairs...
# Batch processing complete.
# Generated 16 QA pairs total
# Saving result to data/generated/cthulhu_293_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_293_qa_pairs.json
# ⠹ Generating qa content from data/output/cthulhu_293.txt...
#  Content saved to data/generated/cthulhu_293_qa_pairs.json
# Doing 7 of remaining 511 files
# Processing 3 chunks to generate QA pairs...
# Batch processing complete.
# Generated 25 QA pairs total
# Saving result to data/generated/cthulhu_539_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_539_qa_pairs.json
# ⠙ Generating qa content from data/output/cthulhu_539.txt...
#  Content saved to data/generated/cthulhu_539_qa_pairs.json
# Doing 8 of remaining 511 files
# Processing 3 chunks to generate QA pairs...
# Batch processing complete.
# Generated 24 QA pairs total
# Saving result to data/generated/cthulhu_525_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_525_qa_pairs.json
# ⠦ Generating qa content from data/output/cthulhu_525.txt...
#  Content saved to data/generated/cthulhu_525_qa_pairs.json
# Doing 9 of remaining 511 files
# Processing 4 chunks to generate QA pairs...
# Batch processing complete.
# Generated 25 QA pairs total
# Saving result to data/generated/cthulhu_264_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_264_qa_pairs.json
# ⠋ Generating qa content from data/output/cthulhu_264.txt...
#  Content saved to data/generated/cthulhu_264_qa_pairs.json
# Doing 10 of remaining 511 files
# Processing 7 chunks to generate QA pairs...
# Batch processing complete.
# Generated 28 QA pairs total
# Saving result to data/generated/cthulhu_207_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_207_qa_pairs.json
# ⠙ Generating qa content from data/output/cthulhu_207.txt...
#  Content saved to data/generated/cthulhu_207_qa_pairs.json
# Doing 11 of remaining 511 files
# Processing 7 chunks to generate QA pairs...
# Batch processing complete.
# Generated 24 QA pairs total
# Saving result to data/generated/cthulhu_167_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_167_qa_pairs.json
# ⠦ Generating qa content from data/output/cthulhu_167.txt...
#  Content saved to data/generated/cthulhu_167_qa_pairs.json
# Doing 12 of remaining 511 files
# Processing 6 chunks to generate QA pairs...
# Batch processing complete.
# Generated 20 QA pairs total
# Saving result to data/generated/cthulhu_298_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_298_qa_pairs.json
# ⠴ Generating qa content from data/output/cthulhu_298.txt...
#  Content saved to data/generated/cthulhu_298_qa_pairs.json
# Doing 13 of remaining 511 files
# Processing 7 chunks to generate QA pairs...
# Batch processing complete.
# Generated 28 QA pairs total
# Saving result to data/generated/cthulhu_208_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_208_qa_pairs.json
# ⠦ Generating qa content from data/output/cthulhu_208.txt...
#  Content saved to data/generated/cthulhu_208_qa_pairs.json
# Doing 14 of remaining 511 files
# Processing 8 chunks to generate QA pairs...
# Batch processing complete.
# Generated 17 QA pairs total
# Saving result to data/generated/cthulhu_135_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_135_qa_pairs.json
# ⠼ Generating qa content from data/output/cthulhu_135.txt...
#  Content saved to data/generated/cthulhu_135_qa_pairs.json
# Doing 15 of remaining 511 files
# Processing 7 chunks to generate QA pairs...
# Batch processing complete.
# Generated 26 QA pairs total
# Saving result to data/generated/cthulhu_164_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_164_qa_pairs.json
# ⠏ Generating qa content from data/output/cthulhu_164.txt...
#  Content saved to data/generated/cthulhu_164_qa_pairs.json
# Doing 16 of remaining 511 files
# Processing 6 chunks to generate QA pairs...
# Batch processing complete.
# Generated 22 QA pairs total
# Saving result to data/generated/cthulhu_150_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_150_qa_pairs.json
# ⠙ Generating qa content from data/output/cthulhu_150.txt...
#  Content saved to data/generated/cthulhu_150_qa_pairs.json
# Doing 17 of remaining 511 files
# Processing 3 chunks to generate QA pairs...
# Batch processing complete.
# Generated 24 QA pairs total
# Saving result to data/generated/cthulhu_549_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_549_qa_pairs.json
# ⠹ Generating qa content from data/output/cthulhu_549.txt...
#  Content saved to data/generated/cthulhu_549_qa_pairs.json
# Doing 18 of remaining 511 files
# Processing 6 chunks to generate QA pairs...
# Batch processing complete.
# Generated 24 QA pairs total
# Saving result to data/generated/cthulhu_71_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_71_qa_pairs.json
# ⠏ Generating qa content from data/output/cthulhu_71.txt...
#  Content saved to data/generated/cthulhu_71_qa_pairs.json
# Doing 19 of remaining 511 files
# Processing 6 chunks to generate QA pairs...
# Batch processing complete.
# Generated 22 QA pairs total
# Saving result to data/generated/cthulhu_426_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_426_qa_pairs.json
# ⠴ Generating qa content from data/output/cthulhu_426.txt...
#  Content saved to data/generated/cthulhu_426_qa_pairs.json
# Doing 20 of remaining 511 files
# Processing 6 chunks to generate QA pairs...
# Batch processing complete.
# Generated 24 QA pairs total
# Saving result to data/generated/cthulhu_402_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_402_qa_pairs.json
# ⠧ Generating qa content from data/output/cthulhu_402.txt...
#  Content saved to data/generated/cthulhu_402_qa_pairs.json
# Doing 21 of remaining 511 files
# Processing 6 chunks to generate QA pairs...
# Batch processing complete.
# Generated 24 QA pairs total
# Saving result to data/generated/cthulhu_228_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_228_qa_pairs.json
# ⠧ Generating qa content from data/output/cthulhu_228.txt...
#  Content saved to data/generated/cthulhu_228_qa_pairs.json
# Doing 22 of remaining 511 files
# Processing 6 chunks to generate QA pairs...
# Batch processing complete.
# Generated 22 QA pairs total
# Saving result to data/generated/cthulhu_262_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_262_qa_pairs.json
# ⠏ Generating qa content from data/output/cthulhu_262.txt...
#  Content saved to data/generated/cthulhu_262_qa_pairs.json
# Doing 23 of remaining 511 files
# Processing 6 chunks to generate QA pairs...
# Batch processing complete.
# Generated 24 QA pairs total
# Saving result to data/generated/cthulhu_357_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_357_qa_pairs.json
# ⠴ Generating qa content from data/output/cthulhu_357.txt...
#  Content saved to data/generated/cthulhu_357_qa_pairs.json
# Doing 24 of remaining 511 files
# Processing 8 chunks to generate QA pairs...
# Batch processing complete.
# Generated 16 QA pairs total
# Saving result to data/generated/cthulhu_56_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_56_qa_pairs.json
# ⠸ Generating qa content from data/output/cthulhu_56.txt...
#  Content saved to data/generated/cthulhu_56_qa_pairs.json
# Doing 25 of remaining 511 files
# Processing 6 chunks to generate QA pairs...
# Batch processing complete.
# Generated 22 QA pairs total
# Saving result to data/generated/cthulhu_226_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_226_qa_pairs.json
# ⠹ Generating qa content from data/output/cthulhu_226.txt...
#  Content saved to data/generated/cthulhu_226_qa_pairs.json
# Doing 26 of remaining 511 files
# Processing 7 chunks to generate QA pairs...
# Batch processing complete.
# Generated 28 QA pairs total
# Saving result to data/generated/cthulhu_444_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_444_qa_pairs.json
# ⠦ Generating qa content from data/output/cthulhu_444.txt...
#  Content saved to data/generated/cthulhu_444_qa_pairs.json
# Doing 27 of remaining 511 files
# Processing 6 chunks to generate QA pairs...
# Batch processing complete.
# Generated 20 QA pairs total
# Saving result to data/generated/cthulhu_123_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_123_qa_pairs.json
# ⠧ Generating qa content from data/output/cthulhu_123.txt...
#  Content saved to data/generated/cthulhu_123_qa_pairs.json
# Doing 28 of remaining 511 files
# Processing 7 chunks to generate QA pairs...
# Batch processing complete.
# Generated 28 QA pairs total
# Saving result to data/generated/cthulhu_163_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_163_qa_pairs.json
# ⠧ Generating qa content from data/output/cthulhu_163.txt...
#  Content saved to data/generated/cthulhu_163_qa_pairs.json
# Doing 29 of remaining 511 files
# Processing 3 chunks to generate QA pairs...
# Batch processing complete.
# Generated 24 QA pairs total
# Saving result to data/generated/cthulhu_483_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_483_qa_pairs.json
# ⠧ Generating qa content from data/output/cthulhu_483.txt...
#  Content saved to data/generated/cthulhu_483_qa_pairs.json
# Doing 30 of remaining 511 files
# Processing 4 chunks to generate QA pairs...
# Batch processing complete.
# Generated 24 QA pairs total
# Saving result to data/generated/cthulhu_508_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_508_qa_pairs.json
# ⠋ Generating qa content from data/output/cthulhu_508.txt...
#  Content saved to data/generated/cthulhu_508_qa_pairs.json
# Doing 31 of remaining 511 files
# Processing 7 chunks to generate QA pairs...
# Batch processing complete.
# Generated 26 QA pairs total
# Saving result to data/generated/cthulhu_476_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_476_qa_pairs.json
# ⠧ Generating qa content from data/output/cthulhu_476.txt...
#  Content saved to data/generated/cthulhu_476_qa_pairs.json
# Doing 32 of remaining 511 files
# Processing 6 chunks to generate QA pairs...
# Batch processing complete.
# Generated 24 QA pairs total
# Saving result to data/generated/cthulhu_428_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_428_qa_pairs.json
# ⠏ Generating qa content from data/output/cthulhu_428.txt...
#  Content saved to data/generated/cthulhu_428_qa_pairs.json
# Doing 33 of remaining 511 files
# Processing 6 chunks to generate QA pairs...
# Batch processing complete.
# Generated 24 QA pairs total
# Saving result to data/generated/cthulhu_506_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_506_qa_pairs.json
# ⠋ Generating qa content from data/output/cthulhu_506.txt...
#  Content saved to data/generated/cthulhu_506_qa_pairs.json
# Doing 34 of remaining 511 files
# Processing 5 chunks to generate QA pairs...
# Batch processing complete.
# Generated 25 QA pairs total
# Saving result to data/generated/cthulhu_427_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_427_qa_pairs.json
# ⠸ Generating qa content from data/output/cthulhu_427.txt...
#  Content saved to data/generated/cthulhu_427_qa_pairs.json
# Doing 35 of remaining 511 files
# Processing 2 chunks to generate QA pairs...
# Batch processing complete.
# Generated 24 QA pairs total
# Saving result to data/generated/cthulhu_534_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_534_qa_pairs.json
# ⠦ Generating qa content from data/output/cthulhu_534.txt...
#  Content saved to data/generated/cthulhu_534_qa_pairs.json
# Doing 36 of remaining 511 files
# Processing 8 chunks to generate QA pairs...
# Batch processing complete.
# Generated 16 QA pairs total
# Saving result to data/generated/cthulhu_205_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_205_qa_pairs.json
# ⠹ Generating qa content from data/output/cthulhu_205.txt...
#  Content saved to data/generated/cthulhu_205_qa_pairs.json
# Doing 37 of remaining 511 files
# Processing 4 chunks to generate QA pairs...
# Batch processing complete.
# Generated 20 QA pairs total
# Saving result to data/generated/cthulhu_336_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_336_qa_pairs.json
# ⠇ Generating qa content from data/output/cthulhu_336.txt...
#  Content saved to data/generated/cthulhu_336_qa_pairs.json
# Doing 38 of remaining 511 files
# Processing 4 chunks to generate QA pairs...
# Batch processing complete.
# Generated 24 QA pairs total
# Saving result to data/generated/cthulhu_76_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_76_qa_pairs.json
# ⠼ Generating qa content from data/output/cthulhu_76.txt...
#  Content saved to data/generated/cthulhu_76_qa_pairs.json
# Doing 39 of remaining 511 files
# Processing 7 chunks to generate QA pairs...
# Batch processing complete.
# Generated 26 QA pairs total
# Saving result to data/generated/cthulhu_54_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_54_qa_pairs.json
# ⠹ Generating qa content from data/output/cthulhu_54.txt...
#  Content saved to data/generated/cthulhu_54_qa_pairs.json
# Doing 40 of remaining 511 files
# Processing 5 chunks to generate QA pairs...
# Batch processing complete.
# Generated 25 QA pairs total
# Saving result to data/generated/cthulhu_408_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_408_qa_pairs.json
# ⠙ Generating qa content from data/output/cthulhu_408.txt...
#  Content saved to data/generated/cthulhu_408_qa_pairs.json
# Doing 41 of remaining 511 files
# Processing 5 chunks to generate QA pairs...
# Batch processing complete.
# Generated 25 QA pairs total
# Saving result to data/generated/cthulhu_474_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_474_qa_pairs.json
# ⠦ Generating qa content from data/output/cthulhu_474.txt...
#  Content saved to data/generated/cthulhu_474_qa_pairs.json
# Doing 42 of remaining 511 files
# Processing 3 chunks to generate QA pairs...
# Batch processing complete.
# Generated 24 QA pairs total
# Saving result to data/generated/cthulhu_171_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_171_qa_pairs.json
# ⠋ Generating qa content from data/output/cthulhu_171.txt...
#  Content saved to data/generated/cthulhu_171_qa_pairs.json
# Doing 43 of remaining 511 files
# Processing 4 chunks to generate QA pairs...
# Batch processing complete.
# Generated 25 QA pairs total
# Saving result to data/generated/cthulhu_45_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_45_qa_pairs.json
# ⠙ Generating qa content from data/output/cthulhu_45.txt...
#  Content saved to data/generated/cthulhu_45_qa_pairs.json
# Doing 44 of remaining 511 files
# Processing 7 chunks to generate QA pairs...
# Batch processing complete.
# Generated 28 QA pairs total
# Saving result to data/generated/cthulhu_192_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_192_qa_pairs.json
# ⠧ Generating qa content from data/output/cthulhu_192.txt...
#  Content saved to data/generated/cthulhu_192_qa_pairs.json
# Doing 45 of remaining 511 files
# Processing 6 chunks to generate QA pairs...
# Batch processing complete.
# Generated 22 QA pairs total
# Saving result to data/generated/cthulhu_116_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_116_qa_pairs.json
# ⠸ Generating qa content from data/output/cthulhu_116.txt...
#  Content saved to data/generated/cthulhu_116_qa_pairs.json
# Doing 46 of remaining 511 files
# Processing 6 chunks to generate QA pairs...
# Batch processing complete.
# Generated 20 QA pairs total
# Saving result to data/generated/cthulhu_304_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_304_qa_pairs.json
# ⠏ Generating qa content from data/output/cthulhu_304.txt...
#  Content saved to data/generated/cthulhu_304_qa_pairs.json
# Doing 47 of remaining 511 files
# Processing 6 chunks to generate QA pairs...
# Batch processing complete.
# Generated 20 QA pairs total
# Saving result to data/generated/cthulhu_334_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_334_qa_pairs.json
# ⠏ Generating qa content from data/output/cthulhu_334.txt...
#  Content saved to data/generated/cthulhu_334_qa_pairs.json
# Doing 48 of remaining 511 files
# Processing 6 chunks to generate QA pairs...
# Batch processing complete.
# Generated 24 QA pairs total
# Saving result to data/generated/cthulhu_404_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_404_qa_pairs.json
# ⠧ Generating qa content from data/output/cthulhu_404.txt...
#  Content saved to data/generated/cthulhu_404_qa_pairs.json
# Doing 49 of remaining 511 files
# Processing 7 chunks to generate QA pairs...
# Batch processing complete.
# Generated 24 QA pairs total
# Saving result to data/generated/cthulhu_143_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_143_qa_pairs.json
# ⠇ Generating qa content from data/output/cthulhu_143.txt...
#  Content saved to data/generated/cthulhu_143_qa_pairs.json
# Doing 50 of remaining 511 files
# Processing 8 chunks to generate QA pairs...
# Batch processing complete.
# Generated 16 QA pairs total
# Saving result to data/generated/cthulhu_322_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_322_qa_pairs.json
# ⠧ Generating qa content from data/output/cthulhu_322.txt...
#  Content saved to data/generated/cthulhu_322_qa_pairs.json
# Doing 51 of remaining 511 files
# Processing 6 chunks to generate QA pairs...
# Batch processing complete.
# Generated 20 QA pairs total
# Saving result to data/generated/cthulhu_155_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_155_qa_pairs.json
# ⠋ Generating qa content from data/output/cthulhu_155.txt...
#  Content saved to data/generated/cthulhu_155_qa_pairs.json
# Doing 52 of remaining 511 files
# Processing 5 chunks to generate QA pairs...
# Batch processing complete.
# Generated 25 QA pairs total
# Saving result to data/generated/cthulhu_412_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_412_qa_pairs.json
# ⠹ Generating qa content from data/output/cthulhu_412.txt...
#  Content saved to data/generated/cthulhu_412_qa_pairs.json
# Doing 53 of remaining 511 files
# Processing 2 chunks to generate QA pairs...
# Batch processing complete.
# Generated 24 QA pairs total
# Saving result to data/generated/cthulhu_531_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_531_qa_pairs.json
# ⠴ Generating qa content from data/output/cthulhu_531.txt...
#  Content saved to data/generated/cthulhu_531_qa_pairs.json
# Doing 54 of remaining 511 files
# Processing 7 chunks to generate QA pairs...
# Batch processing complete.
# Generated 26 QA pairs total
# Saving result to data/generated/cthulhu_120_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_120_qa_pairs.json
# ⠹ Generating qa content from data/output/cthulhu_120.txt...
#  Content saved to data/generated/cthulhu_120_qa_pairs.json
# Doing 55 of remaining 511 files
# Processing 5 chunks to generate QA pairs...
# Batch processing complete.
# Generated 25 QA pairs total
# Saving result to data/generated/cthulhu_57_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_57_qa_pairs.json
# ⠇ Generating qa content from data/output/cthulhu_57.txt...
#  Content saved to data/generated/cthulhu_57_qa_pairs.json
# Doing 56 of remaining 511 files
# Processing 6 chunks to generate QA pairs...
# Batch processing complete.
# Generated 20 QA pairs total
# Saving result to data/generated/cthulhu_446_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_446_qa_pairs.json
# ⠼ Generating qa content from data/output/cthulhu_446.txt...
#  Content saved to data/generated/cthulhu_446_qa_pairs.json
# Doing 57 of remaining 511 files
# Processing 4 chunks to generate QA pairs...
# Batch processing complete.
# Generated 24 QA pairs total
# Saving result to data/generated/cthulhu_142_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_142_qa_pairs.json
# ⠹ Generating qa content from data/output/cthulhu_142.txt...
#  Content saved to data/generated/cthulhu_142_qa_pairs.json
# Doing 58 of remaining 511 files
# Processing 6 chunks to generate QA pairs...
# Batch processing complete.
# Generated 20 QA pairs total
# Saving result to data/generated/cthulhu_277_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_277_qa_pairs.json
# ⠴ Generating qa content from data/output/cthulhu_277.txt...
#  Content saved to data/generated/cthulhu_277_qa_pairs.json
# Doing 59 of remaining 511 files
# Processing 6 chunks to generate QA pairs...
# Batch processing complete.
# Generated 24 QA pairs total
# Saving result to data/generated/cthulhu_179_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_179_qa_pairs.json
# ⠹ Generating qa content from data/output/cthulhu_179.txt...
#  Content saved to data/generated/cthulhu_179_qa_pairs.json
# Doing 60 of remaining 511 files
# Processing 2 chunks to generate QA pairs...
# Batch processing complete.
# Generated 25 QA pairs total
# Saving result to data/generated/cthulhu_514_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_514_qa_pairs.json
# ⠇ Generating qa content from data/output/cthulhu_514.txt...
#  Content saved to data/generated/cthulhu_514_qa_pairs.json
# Doing 61 of remaining 511 files
# Processing 3 chunks to generate QA pairs...
# Batch processing complete.
# Generated 24 QA pairs total
# Saving result to data/generated/cthulhu_553_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_553_qa_pairs.json
# ⠋ Generating qa content from data/output/cthulhu_553.txt...
#  Content saved to data/generated/cthulhu_553_qa_pairs.json
# Doing 62 of remaining 511 files
# Processing 7 chunks to generate QA pairs...
# Batch processing complete.
# Generated 24 QA pairs total
# Saving result to data/generated/cthulhu_96_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_96_qa_pairs.json
# ⠏ Generating qa content from data/output/cthulhu_96.txt...
#  Content saved to data/generated/cthulhu_96_qa_pairs.json
# Doing 63 of remaining 511 files
# Processing 7 chunks to generate QA pairs...
# Batch processing complete.
# Generated 28 QA pairs total
# Saving result to data/generated/cthulhu_337_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_337_qa_pairs.json
# ⠇ Generating qa content from data/output/cthulhu_337.txt...
#  Content saved to data/generated/cthulhu_337_qa_pairs.json
# Doing 64 of remaining 511 files
# Processing 4 chunks to generate QA pairs...
# Batch processing complete.
# Generated 24 QA pairs total
# Saving result to data/generated/cthulhu_294_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_294_qa_pairs.json
# ⠧ Generating qa content from data/output/cthulhu_294.txt...
#  Content saved to data/generated/cthulhu_294_qa_pairs.json
# Doing 65 of remaining 511 files
# Processing 7 chunks to generate QA pairs...
# Batch processing complete.
# Generated 26 QA pairs total
# Saving result to data/generated/cthulhu_263_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_263_qa_pairs.json
# ⠏ Generating qa content from data/output/cthulhu_263.txt...
#  Content saved to data/generated/cthulhu_263_qa_pairs.json
# Doing 66 of remaining 511 files
# Processing 6 chunks to generate QA pairs...
# Batch processing complete.
# Generated 20 QA pairs total
# Saving result to data/generated/cthulhu_303_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_303_qa_pairs.json
# ⠇ Generating qa content from data/output/cthulhu_303.txt...
#  Content saved to data/generated/cthulhu_303_qa_pairs.json
# Doing 67 of remaining 511 files
# Processing 6 chunks to generate QA pairs...
# Batch processing complete.
# Generated 18 QA pairs total
# Saving result to data/generated/cthulhu_125_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_125_qa_pairs.json
# ⠦ Generating qa content from data/output/cthulhu_125.txt...
#  Content saved to data/generated/cthulhu_125_qa_pairs.json
# Doing 68 of remaining 511 files
# Processing 7 chunks to generate QA pairs...
# Batch processing complete.
# Generated 26 QA pairs total
# Saving result to data/generated/cthulhu_102_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_102_qa_pairs.json
# ⠧ Generating qa content from data/output/cthulhu_102.txt...
#  Content saved to data/generated/cthulhu_102_qa_pairs.json
# Doing 69 of remaining 511 files
# Processing 6 chunks to generate QA pairs...
# Batch processing complete.
# Generated 24 QA pairs total
# Saving result to data/generated/cthulhu_112_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_112_qa_pairs.json
# ⠋ Generating qa content from data/output/cthulhu_112.txt...
#  Content saved to data/generated/cthulhu_112_qa_pairs.json
# Doing 70 of remaining 511 files
# Processing 7 chunks to generate QA pairs...
# Batch processing complete.
# Generated 28 QA pairs total
# Saving result to data/generated/cthulhu_178_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_178_qa_pairs.json
# ⠹ Generating qa content from data/output/cthulhu_178.txt...
#  Content saved to data/generated/cthulhu_178_qa_pairs.json
# Doing 71 of remaining 511 files
# Processing 6 chunks to generate QA pairs...
# Batch processing complete.
# Generated 22 QA pairs total
# Saving result to data/generated/cthulhu_331_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_331_qa_pairs.json
# ⠙ Generating qa content from data/output/cthulhu_331.txt...
#  Content saved to data/generated/cthulhu_331_qa_pairs.json
# Doing 72 of remaining 511 files
# Processing 5 chunks to generate QA pairs...
# Batch processing complete.
# Generated 25 QA pairs total
# Saving result to data/generated/cthulhu_77_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_77_qa_pairs.json
# ⠴ Generating qa content from data/output/cthulhu_77.txt...
#  Content saved to data/generated/cthulhu_77_qa_pairs.json
# Doing 73 of remaining 511 files
# Processing 6 chunks to generate QA pairs...
# Batch processing complete.
# Generated 22 QA pairs total
# Saving result to data/generated/cthulhu_141_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_141_qa_pairs.json
# ⠦ Generating qa content from data/output/cthulhu_141.txt...
#  Content saved to data/generated/cthulhu_141_qa_pairs.json
# Doing 74 of remaining 511 files
# Processing 7 chunks to generate QA pairs...
# Batch processing complete.
# Generated 28 QA pairs total
# Saving result to data/generated/cthulhu_280_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_280_qa_pairs.json
# ⠙ Generating qa content from data/output/cthulhu_280.txt...
#  Content saved to data/generated/cthulhu_280_qa_pairs.json
# Doing 75 of remaining 511 files
# Processing 3 chunks to generate QA pairs...
# Batch processing complete.
# Generated 24 QA pairs total
# Saving result to data/generated/cthulhu_550_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_550_qa_pairs.json
# ⠸ Generating qa content from data/output/cthulhu_550.txt...
#  Content saved to data/generated/cthulhu_550_qa_pairs.json
# Doing 76 of remaining 511 files
# Processing 6 chunks to generate QA pairs...
# Batch processing complete.
# Generated 24 QA pairs total
# Saving result to data/generated/cthulhu_216_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_216_qa_pairs.json
# ⠏ Generating qa content from data/output/cthulhu_216.txt...
#  Content saved to data/generated/cthulhu_216_qa_pairs.json
# Doing 77 of remaining 511 files
# Processing 6 chunks to generate QA pairs...
# Batch processing complete.
# Generated 20 QA pairs total
# Saving result to data/generated/cthulhu_118_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_118_qa_pairs.json
# ⠋ Generating qa content from data/output/cthulhu_118.txt...
#  Content saved to data/generated/cthulhu_118_qa_pairs.json
# Doing 78 of remaining 511 files
# Processing 6 chunks to generate QA pairs...
# Batch processing complete.
# Generated 24 QA pairs total
# Saving result to data/generated/cthulhu_34_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_34_qa_pairs.json
# ⠼ Generating qa content from data/output/cthulhu_34.txt...
#  Content saved to data/generated/cthulhu_34_qa_pairs.json
# Doing 79 of remaining 511 files
# Processing 7 chunks to generate QA pairs...
# Batch processing complete.
# Generated 24 QA pairs total
# Saving result to data/generated/cthulhu_162_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_162_qa_pairs.json
# ⠧ Generating qa content from data/output/cthulhu_162.txt...
#  Content saved to data/generated/cthulhu_162_qa_pairs.json
# Doing 80 of remaining 511 files
# Processing 8 chunks to generate QA pairs...
# Batch processing complete.
# Generated 17 QA pairs total
# Saving result to data/generated/cthulhu_421_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_421_qa_pairs.json
# ⠴ Generating qa content from data/output/cthulhu_421.txt...
#  Content saved to data/generated/cthulhu_421_qa_pairs.json
# Doing 81 of remaining 511 files
# Processing 6 chunks to generate QA pairs...
# Batch processing complete.
# Generated 24 QA pairs total
# Saving result to data/generated/cthulhu_470_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_470_qa_pairs.json
# ⠴ Generating qa content from data/output/cthulhu_470.txt...
#  Content saved to data/generated/cthulhu_470_qa_pairs.json
# Doing 82 of remaining 511 files
# Processing 6 chunks to generate QA pairs...
# Batch processing complete.
# Generated 24 QA pairs total
# Saving result to data/generated/cthulhu_98_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_98_qa_pairs.json
# ⠦ Generating qa content from data/output/cthulhu_98.txt...
#  Content saved to data/generated/cthulhu_98_qa_pairs.json
# Doing 83 of remaining 511 files
# Processing 7 chunks to generate QA pairs...
# Batch processing complete.
# Generated 28 QA pairs total
# Saving result to data/generated/cthulhu_272_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_272_qa_pairs.json
# ⠧ Generating qa content from data/output/cthulhu_272.txt...
#  Content saved to data/generated/cthulhu_272_qa_pairs.json
# Doing 84 of remaining 511 files
# Processing 8 chunks to generate QA pairs...
# Batch processing complete.
# Generated 16 QA pairs total
# Saving result to data/generated/cthulhu_128_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_128_qa_pairs.json
# ⠴ Generating qa content from data/output/cthulhu_128.txt...
#  Content saved to data/generated/cthulhu_128_qa_pairs.json
# Doing 85 of remaining 511 files
# Processing 7 chunks to generate QA pairs...
# Batch processing complete.
# Generated 22 QA pairs total
# Saving result to data/generated/cthulhu_382_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_382_qa_pairs.json
# ⠧ Generating qa content from data/output/cthulhu_382.txt...
#  Content saved to data/generated/cthulhu_382_qa_pairs.json
# Doing 86 of remaining 511 files
# Processing 5 chunks to generate QA pairs...
# Batch processing complete.
# Generated 25 QA pairs total
# Saving result to data/generated/cthulhu_124_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_124_qa_pairs.json
# ⠧ Generating qa content from data/output/cthulhu_124.txt...
#  Content saved to data/generated/cthulhu_124_qa_pairs.json
# Doing 87 of remaining 511 files
# Processing 6 chunks to generate QA pairs...
# Batch processing complete.
# Generated 24 QA pairs total
# Saving result to data/generated/cthulhu_206_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_206_qa_pairs.json
# ⠴ Generating qa content from data/output/cthulhu_206.txt...
#  Content saved to data/generated/cthulhu_206_qa_pairs.json
# Doing 88 of remaining 511 files
# Processing 6 chunks to generate QA pairs...
# Batch processing complete.
# Generated 18 QA pairs total
# Saving result to data/generated/cthulhu_371_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_371_qa_pairs.json
# ⠙ Generating qa content from data/output/cthulhu_371.txt...
#  Content saved to data/generated/cthulhu_371_qa_pairs.json
# Doing 89 of remaining 511 files
# Processing 7 chunks to generate QA pairs...
# Batch processing complete.
# Generated 24 QA pairs total
# Saving result to data/generated/cthulhu_291_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_291_qa_pairs.json
# ⠇ Generating qa content from data/output/cthulhu_291.txt...
#  Content saved to data/generated/cthulhu_291_qa_pairs.json
# Doing 90 of remaining 511 files
# Processing 6 chunks to generate QA pairs...
# Batch processing complete.
# Generated 18 QA pairs total
# Saving result to data/generated/cthulhu_361_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_361_qa_pairs.json
# ⠇ Generating qa content from data/output/cthulhu_361.txt...
#  Content saved to data/generated/cthulhu_361_qa_pairs.json
# Doing 91 of remaining 511 files
# Processing 5 chunks to generate QA pairs...
# Batch processing complete.
# Generated 25 QA pairs total
# Saving result to data/generated/cthulhu_500_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_500_qa_pairs.json
# ⠋ Generating qa content from data/output/cthulhu_500.txt...
#  Content saved to data/generated/cthulhu_500_qa_pairs.json
# Doing 92 of remaining 511 files
# Processing 5 chunks to generate QA pairs...
# Batch processing complete.
# Generated 25 QA pairs total
# Saving result to data/generated/cthulhu_450_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_450_qa_pairs.json
# ⠴ Generating qa content from data/output/cthulhu_450.txt...
#  Content saved to data/generated/cthulhu_450_qa_pairs.json
# Doing 93 of remaining 511 files
# Processing 8 chunks to generate QA pairs...
# Batch processing complete.
# Generated 17 QA pairs total
# Saving result to data/generated/cthulhu_79_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_79_qa_pairs.json
# ⠴ Generating qa content from data/output/cthulhu_79.txt...
#  Content saved to data/generated/cthulhu_79_qa_pairs.json
# Doing 94 of remaining 511 files
# Processing 6 chunks to generate QA pairs...
# Batch processing complete.
# Generated 20 QA pairs total
# Saving result to data/generated/cthulhu_292_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_292_qa_pairs.json
# ⠦ Generating qa content from data/output/cthulhu_292.txt...
#  Content saved to data/generated/cthulhu_292_qa_pairs.json
# Doing 95 of remaining 511 files
# Processing 8 chunks to generate QA pairs...
# Batch processing complete.
# Generated 16 QA pairs total
# Saving result to data/generated/cthulhu_93_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_93_qa_pairs.json
# ⠇ Generating qa content from data/output/cthulhu_93.txt...
#  Content saved to data/generated/cthulhu_93_qa_pairs.json
# Doing 96 of remaining 511 files
# Processing 6 chunks to generate QA pairs...
# Batch processing complete.
# Generated 24 QA pairs total
# Saving result to data/generated/cthulhu_97_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_97_qa_pairs.json
# ⠦ Generating qa content from data/output/cthulhu_97.txt...
#  Content saved to data/generated/cthulhu_97_qa_pairs.json
# Doing 97 of remaining 511 files
# Processing 7 chunks to generate QA pairs...
# Batch processing complete.
# Generated 24 QA pairs total
# Saving result to data/generated/cthulhu_195_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_195_qa_pairs.json
# ⠸ Generating qa content from data/output/cthulhu_195.txt...
#  Content saved to data/generated/cthulhu_195_qa_pairs.json
# Doing 98 of remaining 511 files
# Processing 3 chunks to generate QA pairs...
# Batch processing complete.
# Generated 24 QA pairs total
# Saving result to data/generated/cthulhu_512_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_512_qa_pairs.json
# ⠹ Generating qa content from data/output/cthulhu_512.txt...
#  Content saved to data/generated/cthulhu_512_qa_pairs.json
# Doing 99 of remaining 511 files
# Processing 6 chunks to generate QA pairs...
# Batch processing complete.
# Generated 22 QA pairs total
# Saving result to data/generated/cthulhu_320_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_320_qa_pairs.json
# ⠏ Generating qa content from data/output/cthulhu_320.txt...
#  Content saved to data/generated/cthulhu_320_qa_pairs.json
# Doing 100 of remaining 511 files
# Processing 7 chunks to generate QA pairs...
# Batch processing complete.
# Generated 28 QA pairs total
# Saving result to data/generated/cthulhu_82_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_82_qa_pairs.json
# ⠦ Generating qa content from data/output/cthulhu_82.txt...
#  Content saved to data/generated/cthulhu_82_qa_pairs.json
# Doing 101 of remaining 511 files
# Processing 3 chunks to generate QA pairs...
# Batch processing complete.
# Generated 24 QA pairs total
# Saving result to data/generated/cthulhu_522_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_522_qa_pairs.json
# ⠇ Generating qa content from data/output/cthulhu_522.txt...
#  Content saved to data/generated/cthulhu_522_qa_pairs.json
# Doing 102 of remaining 511 files
# Processing 6 chunks to generate QA pairs...
# Batch processing complete.
# Generated 24 QA pairs total
# Saving result to data/generated/cthulhu_296_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_296_qa_pairs.json
# ⠧ Generating qa content from data/output/cthulhu_296.txt...
#  Content saved to data/generated/cthulhu_296_qa_pairs.json
# Doing 103 of remaining 511 files
# Processing 6 chunks to generate QA pairs...
# Batch processing complete.
# Generated 24 QA pairs total
# Saving result to data/generated/cthulhu_308_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_308_qa_pairs.json
# ⠴ Generating qa content from data/output/cthulhu_308.txt...
#  Content saved to data/generated/cthulhu_308_qa_pairs.json
# Doing 104 of remaining 511 files
# Processing 7 chunks to generate QA pairs...
# Batch processing complete.
# Generated 28 QA pairs total
# Saving result to data/generated/cthulhu_373_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_373_qa_pairs.json
# ⠇ Generating qa content from data/output/cthulhu_373.txt...
#  Content saved to data/generated/cthulhu_373_qa_pairs.json
# Doing 105 of remaining 511 files
# Processing 6 chunks to generate QA pairs...
# Batch processing complete.
# Generated 22 QA pairs total
# Saving result to data/generated/cthulhu_478_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_478_qa_pairs.json
# ⠦ Generating qa content from data/output/cthulhu_478.txt...
#  Content saved to data/generated/cthulhu_478_qa_pairs.json
# Doing 106 of remaining 511 files
# Processing 2 chunks to generate QA pairs...
# Batch processing complete.
# Generated 26 QA pairs total
# Saving result to data/generated/cthulhu_532_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_532_qa_pairs.json
# ⠧ Generating qa content from data/output/cthulhu_532.txt...
#  Content saved to data/generated/cthulhu_532_qa_pairs.json
# Doing 107 of remaining 511 files
# Processing 6 chunks to generate QA pairs...
# Batch processing complete.
# Generated 24 QA pairs total
# Saving result to data/generated/cthulhu_283_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_283_qa_pairs.json
# ⠙ Generating qa content from data/output/cthulhu_283.txt...
#  Content saved to data/generated/cthulhu_283_qa_pairs.json
# Doing 108 of remaining 511 files
# Processing 6 chunks to generate QA pairs...
# Batch processing complete.
# Generated 24 QA pairs total
# Saving result to data/generated/cthulhu_60_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_60_qa_pairs.json
# ⠦ Generating qa content from data/output/cthulhu_60.txt...
#  Content saved to data/generated/cthulhu_60_qa_pairs.json
# Doing 109 of remaining 511 files
# Processing 5 chunks to generate QA pairs...
# Batch processing complete.
# Generated 25 QA pairs total
# Saving result to data/generated/cthulhu_327_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_327_qa_pairs.json
# ⠹ Generating qa content from data/output/cthulhu_327.txt...
# ...
#  Content saved to data/generated/cthulhu_149_qa_pairs.json
# Doing 476 of remaining 511 files
# Processing 6 chunks to generate QA pairs...
# Batch processing complete.
# Generated 24 QA pairs total
# Saving result to data/generated/cthulhu_198_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_198_qa_pairs.json
# ⠇ Generating qa content from data/output/cthulhu_198.txt...
#  Content saved to data/generated/cthulhu_198_qa_pairs.json
# Doing 477 of remaining 511 files
# Processing 8 chunks to generate QA pairs...
# Batch processing complete.
# Generated 16 QA pairs total
# Saving result to data/generated/cthulhu_239_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_239_qa_pairs.json
# ⠙ Generating qa content from data/output/cthulhu_239.txt...
#  Content saved to data/generated/cthulhu_239_qa_pairs.json
# Doing 478 of remaining 511 files
# Processing 3 chunks to generate QA pairs...
# Batch processing complete.
# Generated 18 QA pairs total
# Saving result to data/generated/cthulhu_489_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_489_qa_pairs.json
# ⠼ Generating qa content from data/output/cthulhu_489.txt...
#  Content saved to data/generated/cthulhu_489_qa_pairs.json
# Doing 479 of remaining 511 files
# Processing 5 chunks to generate QA pairs...
# Batch processing complete.
# Generated 25 QA pairs total
# Saving result to data/generated/cthulhu_367_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_367_qa_pairs.json
# ⠹ Generating qa content from data/output/cthulhu_367.txt...
#  Content saved to data/generated/cthulhu_367_qa_pairs.json
# Doing 480 of remaining 511 files
# Processing 6 chunks to generate QA pairs...
# Batch processing complete.
# Generated 22 QA pairs total
# Saving result to data/generated/cthulhu_33_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_33_qa_pairs.json
# ⠇ Generating qa content from data/output/cthulhu_33.txt...
#  Content saved to data/generated/cthulhu_33_qa_pairs.json
# Doing 481 of remaining 511 files
# Processing 7 chunks to generate QA pairs...
# Batch processing complete.
# Generated 26 QA pairs total
# Saving result to data/generated/cthulhu_111_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_111_qa_pairs.json
# ⠼ Generating qa content from data/output/cthulhu_111.txt...
#  Content saved to data/generated/cthulhu_111_qa_pairs.json
# Doing 482 of remaining 511 files
# Processing 5 chunks to generate QA pairs...
# Batch processing complete.
# Generated 25 QA pairs total
# Saving result to data/generated/cthulhu_184_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_184_qa_pairs.json
# ⠋ Generating qa content from data/output/cthulhu_184.txt...
#  Content saved to data/generated/cthulhu_184_qa_pairs.json
# Doing 483 of remaining 511 files
# Processing 6 chunks to generate QA pairs...
# Batch processing complete.
# Generated 24 QA pairs total
# Saving result to data/generated/cthulhu_398_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_398_qa_pairs.json
# ⠙ Generating qa content from data/output/cthulhu_398.txt...
#  Content saved to data/generated/cthulhu_398_qa_pairs.json
# Doing 484 of remaining 511 files
# Processing 7 chunks to generate QA pairs...
# Batch processing complete.
# Generated 28 QA pairs total
# Saving result to data/generated/cthulhu_199_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_199_qa_pairs.json
# ⠙ Generating qa content from data/output/cthulhu_199.txt...
#  Content saved to data/generated/cthulhu_199_qa_pairs.json
# Doing 485 of remaining 511 files
# Processing 6 chunks to generate QA pairs...
# Batch processing complete.
# Generated 20 QA pairs total
# Saving result to data/generated/cthulhu_273_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_273_qa_pairs.json
# ⠙ Generating qa content from data/output/cthulhu_273.txt...
#  Content saved to data/generated/cthulhu_273_qa_pairs.json
# Doing 486 of remaining 511 files
# Processing 7 chunks to generate QA pairs...
# Batch processing complete.
# Generated 28 QA pairs total
# Saving result to data/generated/cthulhu_463_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_463_qa_pairs.json
# ⠴ Generating qa content from data/output/cthulhu_463.txt...
#  Content saved to data/generated/cthulhu_463_qa_pairs.json
# Doing 487 of remaining 511 files
# Processing 6 chunks to generate QA pairs...
# Batch processing complete.
# Generated 22 QA pairs total
# Saving result to data/generated/cthulhu_109_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_109_qa_pairs.json
# ⠦ Generating qa content from data/output/cthulhu_109.txt...
#  Content saved to data/generated/cthulhu_109_qa_pairs.json
# Doing 488 of remaining 511 files
# Processing 2 chunks to generate QA pairs...
# Batch processing complete.
# Generated 29 QA pairs total
# Saving result to data/generated/cthulhu_491_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_491_qa_pairs.json
# ⠋ Generating qa content from data/output/cthulhu_491.txt...
#  Content saved to data/generated/cthulhu_491_qa_pairs.json
# Doing 489 of remaining 511 files
# Processing 7 chunks to generate QA pairs...
# Batch processing complete.
# Generated 26 QA pairs total
# Saving result to data/generated/cthulhu_218_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_218_qa_pairs.json
# ⠇ Generating qa content from data/output/cthulhu_218.txt...
#  Content saved to data/generated/cthulhu_218_qa_pairs.json
# Doing 490 of remaining 511 files
# Processing 3 chunks to generate QA pairs...
# Batch processing complete.
# Generated 27 QA pairs total
# Saving result to data/generated/cthulhu_543_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_543_qa_pairs.json
# ⠼ Generating qa content from data/output/cthulhu_543.txt...
#  Content saved to data/generated/cthulhu_543_qa_pairs.json
# Doing 491 of remaining 511 files
# Processing 6 chunks to generate QA pairs...
# Batch processing complete.
# Generated 20 QA pairs total
# Saving result to data/generated/cthulhu_448_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_448_qa_pairs.json
# ⠇ Generating qa content from data/output/cthulhu_448.txt...
#  Content saved to data/generated/cthulhu_448_qa_pairs.json
# Doing 492 of remaining 511 files
# Processing 5 chunks to generate QA pairs...
# Batch processing complete.
# Generated 25 QA pairs total
# Saving result to data/generated/cthulhu_497_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_497_qa_pairs.json
# ⠇ Generating qa content from data/output/cthulhu_497.txt...
#  Content saved to data/generated/cthulhu_497_qa_pairs.json
# Doing 493 of remaining 511 files
# Processing 7 chunks to generate QA pairs...
# Batch processing complete.
# Generated 26 QA pairs total
# Saving result to data/generated/cthulhu_287_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_287_qa_pairs.json
# ⠇ Generating qa content from data/output/cthulhu_287.txt...
#  Content saved to data/generated/cthulhu_287_qa_pairs.json
# Doing 494 of remaining 511 files
# Processing 7 chunks to generate QA pairs...
# Batch processing complete.
# Generated 28 QA pairs total
# Saving result to data/generated/cthulhu_315_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_315_qa_pairs.json
# ⠇ Generating qa content from data/output/cthulhu_315.txt...
#  Content saved to data/generated/cthulhu_315_qa_pairs.json
# Doing 495 of remaining 511 files
# Processing 3 chunks to generate QA pairs...
# Batch processing complete.
# Generated 25 QA pairs total
# Saving result to data/generated/cthulhu_537_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_537_qa_pairs.json
# ⠹ Generating qa content from data/output/cthulhu_537.txt...
#  Content saved to data/generated/cthulhu_537_qa_pairs.json
# Doing 496 of remaining 511 files
# Processing 7 chunks to generate QA pairs...
# Batch processing complete.
# Generated 20 QA pairs total
# Saving result to data/generated/cthulhu_121_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_121_qa_pairs.json
# ⠙ Generating qa content from data/output/cthulhu_121.txt...
#  Content saved to data/generated/cthulhu_121_qa_pairs.json
# Doing 497 of remaining 511 files
# Processing 6 chunks to generate QA pairs...
# Batch processing complete.
# Generated 22 QA pairs total
# Saving result to data/generated/cthulhu_393_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_393_qa_pairs.json
# ⠦ Generating qa content from data/output/cthulhu_393.txt...
#  Content saved to data/generated/cthulhu_393_qa_pairs.json
# Doing 498 of remaining 511 files
# Processing 3 chunks to generate QA pairs...
# Batch processing complete.
# Generated 25 QA pairs total
# Saving result to data/generated/cthulhu_552_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_552_qa_pairs.json
# ⠦ Generating qa content from data/output/cthulhu_552.txt...
#  Content saved to data/generated/cthulhu_552_qa_pairs.json
# Doing 499 of remaining 511 files
# Processing 5 chunks to generate QA pairs...
# Batch processing complete.
# Generated 22 QA pairs total
# Saving result to data/generated/cthulhu_295_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_295_qa_pairs.json
# ⠙ Generating qa content from data/output/cthulhu_295.txt...
#  Content saved to data/generated/cthulhu_295_qa_pairs.json
# Doing 500 of remaining 511 files
# Processing 8 chunks to generate QA pairs...
# Batch processing complete.
# Generated 17 QA pairs total
# Saving result to data/generated/cthulhu_475_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_475_qa_pairs.json
# ⠸ Generating qa content from data/output/cthulhu_475.txt...
#  Content saved to data/generated/cthulhu_475_qa_pairs.json
# Doing 501 of remaining 511 files
# Processing 6 chunks to generate QA pairs...
# Batch processing complete.
# Generated 24 QA pairs total
# Saving result to data/generated/cthulhu_241_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_241_qa_pairs.json
# ⠴ Generating qa content from data/output/cthulhu_241.txt...
#  Content saved to data/generated/cthulhu_241_qa_pairs.json
# Doing 502 of remaining 511 files
# Processing 6 chunks to generate QA pairs...
# Batch processing complete.
# Generated 22 QA pairs total
# Saving result to data/generated/cthulhu_297_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_297_qa_pairs.json
# ⠋ Generating qa content from data/output/cthulhu_297.txt...
#  Content saved to data/generated/cthulhu_297_qa_pairs.json
# Doing 503 of remaining 511 files
# Processing 3 chunks to generate QA pairs...
# Batch processing complete.
# Generated 23 QA pairs total
# Saving result to data/generated/cthulhu_542_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_542_qa_pairs.json
# ⠸ Generating qa content from data/output/cthulhu_542.txt...
#  Content saved to data/generated/cthulhu_542_qa_pairs.json
# Doing 504 of remaining 511 files
# Processing 7 chunks to generate QA pairs...
# Batch processing complete.
# Generated 25 QA pairs total
# Saving result to data/generated/cthulhu_247_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_247_qa_pairs.json
# ⠙ Generating qa content from data/output/cthulhu_247.txt...
#  Content saved to data/generated/cthulhu_247_qa_pairs.json
# Doing 505 of remaining 511 files
# Processing 5 chunks to generate QA pairs...
# Batch processing complete.
# Generated 25 QA pairs total
# Saving result to data/generated/cthulhu_259_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_259_qa_pairs.json
# ⠸ Generating qa content from data/output/cthulhu_259.txt...
#  Content saved to data/generated/cthulhu_259_qa_pairs.json
# Doing 506 of remaining 511 files
# Processing 8 chunks to generate QA pairs...
# Batch processing complete.
# Generated 16 QA pairs total
# Saving result to data/generated/cthulhu_49_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_49_qa_pairs.json
# ⠦ Generating qa content from data/output/cthulhu_49.txt...
#  Content saved to data/generated/cthulhu_49_qa_pairs.json
# Doing 507 of remaining 511 files
# Processing 5 chunks to generate QA pairs...
# Batch processing complete.
# Generated 25 QA pairs total
# Saving result to data/generated/cthulhu_452_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_452_qa_pairs.json
# ⠹ Generating qa content from data/output/cthulhu_452.txt...
#  Content saved to data/generated/cthulhu_452_qa_pairs.json
# Doing 508 of remaining 511 files
# Processing 6 chunks to generate QA pairs...
# Batch processing complete.
# Generated 24 QA pairs total
# Saving result to data/generated/cthulhu_193_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_193_qa_pairs.json
# ⠦ Generating qa content from data/output/cthulhu_193.txt...
#  Content saved to data/generated/cthulhu_193_qa_pairs.json
# Doing 509 of remaining 511 files
# Processing 6 chunks to generate QA pairs...
# Batch processing complete.
# Generated 24 QA pairs total
# Saving result to data/generated/cthulhu_220_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_220_qa_pairs.json
# ⠴ Generating qa content from data/output/cthulhu_220.txt...
#  Content saved to data/generated/cthulhu_220_qa_pairs.json
# Doing 510 of remaining 511 files
# Processing 7 chunks to generate QA pairs...
# Batch processing complete.
# Generated 28 QA pairs total
# Saving result to data/generated/cthulhu_175_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_175_qa_pairs.json
# ⠦ Generating qa content from data/output/cthulhu_175.txt...
#  Content saved to data/generated/cthulhu_175_qa_pairs.json
# Doing 511 of remaining 511 files
# Processing 5 chunks to generate QA pairs...
# Batch processing complete.
# Generated 22 QA pairs total
# Saving result to data/generated/cthulhu_338_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_338_qa_pairs.json
# ⠧ Generating qa content from data/output/cthulhu_338.txt...
#  Content saved to data/generated/cthulhu_338_qa_pairs.json

# %%
# store generated QA pair files in github so that we don't loose them when we
# close the notebook

! git config --global user.email "marco.pennacchiotti@gmail.com"
! git add data/generated
! git commit -m "added new qa pairs"
! git push origin main
# Out:
# [main d6414ed] added new qa pairs
#  511 files changed, 50403 insertions(+)
#  create mode 100644 data/generated/cthulhu_100_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_101_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_102_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_103_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_104_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_105_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_106_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_107_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_108_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_109_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_110_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_111_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_112_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_113_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_114_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_115_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_116_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_117_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_118_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_119_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_120_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_121_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_122_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_123_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_124_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_125_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_126_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_127_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_128_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_129_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_130_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_131_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_132_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_133_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_134_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_135_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_136_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_137_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_138_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_139_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_140_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_141_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_142_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_143_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_144_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_145_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_146_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_147_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_148_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_149_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_150_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_151_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_152_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_153_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_154_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_155_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_156_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_157_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_158_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_159_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_161_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_162_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_163_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_164_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_165_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_166_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_167_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_168_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_169_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_170_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_171_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_172_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_173_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_174_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_175_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_176_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_177_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_178_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_179_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_180_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_181_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_182_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_183_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_184_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_185_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_186_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_187_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_188_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_189_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_191_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_192_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_193_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_194_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_195_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_196_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_197_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_198_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_199_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_200_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_201_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_202_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_203_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_204_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_205_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_206_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_207_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_208_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_209_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_210_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_211_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_212_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_213_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_214_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_215_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_216_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_217_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_218_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_219_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_220_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_221_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_222_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_223_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_224_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_225_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_226_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_227_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_228_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_229_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_230_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_231_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_232_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_233_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_234_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_235_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_236_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_237_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_238_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_239_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_240_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_241_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_242_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_243_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_244_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_245_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_246_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_247_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_248_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_249_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_250_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_252_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_253_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_254_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_256_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_257_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_258_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_259_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_260_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_261_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_262_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_263_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_264_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_265_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_267_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_268_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_270_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_271_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_272_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_273_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_274_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_275_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_276_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_277_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_278_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_280_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_281_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_282_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_283_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_284_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_285_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_286_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_287_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_288_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_289_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_290_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_291_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_292_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_293_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_294_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_295_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_296_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_297_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_298_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_299_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_300_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_301_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_302_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_303_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_304_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_305_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_306_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_307_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_308_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_309_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_30_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_310_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_311_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_312_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_313_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_315_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_316_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_317_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_318_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_319_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_31_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_320_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_321_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_322_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_323_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_324_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_325_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_326_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_327_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_328_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_329_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_32_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_330_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_331_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_332_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_333_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_334_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_335_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_336_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_337_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_338_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_339_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_33_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_340_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_341_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_342_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_343_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_344_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_345_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_346_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_347_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_348_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_349_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_34_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_350_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_351_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_352_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_353_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_354_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_355_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_356_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_357_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_358_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_359_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_35_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_360_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_361_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_362_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_363_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_364_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_365_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_366_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_367_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_368_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_369_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_36_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_370_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_371_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_372_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_373_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_374_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_375_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_376_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_377_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_378_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_37_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_380_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_381_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_382_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_383_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_384_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_385_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_386_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_387_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_388_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_389_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_38_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_390_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_392_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_393_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_394_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_396_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_397_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_398_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_399_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_400_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_401_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_402_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_403_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_404_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_405_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_406_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_407_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_408_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_409_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_40_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_410_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_411_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_412_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_413_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_414_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_415_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_416_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_417_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_418_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_419_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_41_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_420_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_421_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_422_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_423_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_424_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_425_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_426_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_427_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_428_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_429_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_42_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_430_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_431_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_432_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_433_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_434_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_435_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_436_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_437_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_438_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_439_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_43_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_440_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_441_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_442_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_443_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_444_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_445_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_446_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_447_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_448_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_449_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_450_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_452_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_453_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_454_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_455_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_456_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_458_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_459_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_45_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_460_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_461_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_462_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_463_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_464_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_465_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_466_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_467_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_468_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_469_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_46_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_470_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_471_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_472_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_473_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_474_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_475_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_476_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_477_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_478_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_479_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_47_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_480_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_481_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_482_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_483_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_484_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_485_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_486_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_487_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_488_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_489_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_48_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_490_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_491_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_493_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_494_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_495_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_496_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_497_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_498_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_499_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_49_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_500_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_501_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_502_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_503_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_504_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_505_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_506_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_507_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_508_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_509_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_50_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_510_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_511_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_512_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_513_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_514_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_515_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_516_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_517_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_518_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_519_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_51_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_520_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_521_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_522_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_523_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_524_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_525_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_526_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_527_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_528_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_529_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_52_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_530_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_531_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_532_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_533_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_534_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_535_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_536_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_537_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_538_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_539_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_53_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_540_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_541_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_542_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_543_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_544_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_545_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_546_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_547_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_548_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_549_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_54_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_550_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_551_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_552_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_553_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_554_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_555_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_556_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_557_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_558_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_559_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_55_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_56_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_57_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_58_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_59_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_60_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_61_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_62_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_63_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_64_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_65_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_66_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_67_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_69_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_70_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_71_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_72_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_73_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_74_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_75_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_76_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_77_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_78_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_79_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_80_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_81_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_82_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_83_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_84_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_85_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_86_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_87_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_88_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_89_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_91_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_92_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_93_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_94_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_95_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_96_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_97_qa_pairs.json
#  create mode 100644 data/generated/cthulhu_98_qa_pairs.json
# Enumerating objects: 518, done.
# Counting objects: 100% (518/518), done.
# Delta compression using up to 12 threads
# Compressing objects: 100% (515/515), done.
# Writing objects: 100% (515/515), 678.12 KiB | 3.26 MiB/s, done.
# Total 515 (delta 6), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (6/6), done.
# To github.com:ellolo/cthulhu_fine_tuning.git
#    67ce717..d6414ed  main -> main

# %%
# double check that the generated json files are correct

import glob
import json

# %cd /content/cthulhu_fine_tuning/
gen_dir = "data/generated/*qa_pairs.json"

bad_count = 0
fnames = glob.glob(gen_dir)
for fname in fnames:
  is_bad = False
  with open(fname, 'r', encoding='utf-8') as f:
    try:
      data = json.load(f)
      if not "summary" in data:
        print(f"{fname}: missing field summary.")
        is_bad = True
      if "summary" in data and len(data["summary"]) < 10:
        print(f"{fname}: missing summary text.")
        is_bad = True
      if not "qa_pairs" in data:
        print(f"{fname}: missing field qa_pairs.")
        is_bad = True
      if "qa_pairs" in data and len(data["qa_pairs"]) == 0:
        print(f"{fname}: missing qa pairs.")
        is_bad = True
      bad_count += is_bad
    except json.JSONDecodeError:
      print(f"{fname}: not a valid json.")
      bad_count += 1

print(f"Number of badly generated files: {bad_count} of total {len(fnames)}")
# Out:
# /content/cthulhu_fine_tuning
# Number of badly generated files: 0 of total 560

# %% [markdown]
# ## Curate QA pairs

# %%
# CURATE QA PAIRS
#
# Filters out low quality QA pairs. This is done by prompting the same vllm that
# generated the pairs, to score them according to accuracy (0-3), relevance
# (0-2), clarity (0-2) and usefulness (0-3). Only pairs which have a summed
# score above a threshold (0 to 10, where 10 is highest quality) are retained
#and saved in the output directory. Prompt for rating here:
# https://github.com/meta-llama/synthetic-data-kit/blob/main/configs/config.yaml
#
# vllm needs to be up and running to run this code.
#
# This takes about 1.5 hours and 10 compute units on a A100 GPU environment.

import glob
from pathlib import Path


# %cd /content/cthulhu_fine_tuning/
gen_dir = "data/generated/*qa_pairs.json"
clean_dir = "data/cleaned"
Path(clean_dir).mkdir(parents=True, exist_ok=True)

i = 0
fnames = glob.glob(gen_dir)
for fname in fnames:
  out_fname_base = f"{Path(fname).stem}_clean.json"
  out_fname = Path(clean_dir,out_fname_base)
  print(out_fname)
  print(f"Doing {i+1} of {len(fnames)} files")
  if not out_fname.exists():
    ! synthetic-data-kit \
        -c synthetic_data_kit_config.yaml \
        curate \
        --threshold 6 \
        --output {out_fname} \
        {fname}
  else:
    print(f"{out_fname} already done, skipping!")
  i += 1
# Out:
# Streaming output truncated to the last 5000 lines.
# Rated 22 QA pairs
# Retained 22 pairs (threshold: 6.0)
# Average score: 8.1
# ⠇ Cleaning content from data/generated/cthulhu_339_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_339_qa_pairs_clean.json
# data/cleaned/cthulhu_359_qa_pairs_clean.json
# Doing 6 of 560 files
# Processing 3 batches of QA pairs...
# Batch processing complete.
# Rated 24 QA pairs
# Retained 22 pairs (threshold: 6.0)
# Average score: 7.7
# ⠴ Cleaning content from data/generated/cthulhu_359_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_359_qa_pairs_clean.json
# data/cleaned/cthulhu_405_qa_pairs_clean.json
# Doing 7 of 560 files
# Processing 4 batches of QA pairs...
# Batch processing complete.
# Rated 28 QA pairs
# Retained 28 pairs (threshold: 6.0)
# Average score: 8.1
# ⠼ Cleaning content from data/generated/cthulhu_405_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_405_qa_pairs_clean.json
# data/cleaned/cthulhu_282_qa_pairs_clean.json
# Doing 8 of 560 files
# Processing 3 batches of QA pairs...
# Batch processing complete.
# Rated 20 QA pairs
# Retained 20 pairs (threshold: 6.0)
# Average score: 8.1
# ⠏ Cleaning content from data/generated/cthulhu_282_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_282_qa_pairs_clean.json
# data/cleaned/cthulhu_133_qa_pairs_clean.json
# Doing 9 of 560 files
# Processing 3 batches of QA pairs...
# Batch processing complete.
# Rated 20 QA pairs
# Retained 20 pairs (threshold: 6.0)
# Average score: 8.4
# ⠴ Cleaning content from data/generated/cthulhu_133_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_133_qa_pairs_clean.json
# data/cleaned/cthulhu_274_qa_pairs_clean.json
# Doing 10 of 560 files
# Processing 3 batches of QA pairs...
# Batch processing complete.
# Rated 20 QA pairs
# Retained 16 pairs (threshold: 6.0)
# Average score: 7.2
# ⠸ Cleaning content from data/generated/cthulhu_274_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_274_qa_pairs_clean.json
# data/cleaned/cthulhu_310_qa_pairs_clean.json
# Doing 11 of 560 files
# Processing 4 batches of QA pairs...
# Batch processing complete.
# Rated 25 QA pairs
# Retained 24 pairs (threshold: 6.0)
# Average score: 7.8
# ⠼ Cleaning content from data/generated/cthulhu_310_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_310_qa_pairs_clean.json
# data/cleaned/cthulhu_518_qa_pairs_clean.json
# Doing 12 of 560 files
# Processing 3 batches of QA pairs...
# Batch processing complete.
# Rated 20 QA pairs
# Retained 20 pairs (threshold: 6.0)
# Average score: 8.2
# ⠇ Cleaning content from data/generated/cthulhu_518_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_518_qa_pairs_clean.json
# data/cleaned/cthulhu_251_qa_pairs_clean.json
# Doing 13 of 560 files
# Processing 4 batches of QA pairs...
# Batch processing complete.
# Rated 26 QA pairs
# Retained 25 pairs (threshold: 6.0)
# Average score: 8.0
# ⠙ Cleaning content from data/generated/cthulhu_251_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_251_qa_pairs_clean.json
# data/cleaned/cthulhu_259_qa_pairs_clean.json
# Doing 14 of 560 files
# Processing 4 batches of QA pairs...
# Batch processing complete.
# Rated 25 QA pairs
# Retained 25 pairs (threshold: 6.0)
# Average score: 8.4
# ⠼ Cleaning content from data/generated/cthulhu_259_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_259_qa_pairs_clean.json
# data/cleaned/cthulhu_500_qa_pairs_clean.json
# Doing 15 of 560 files
# Processing 4 batches of QA pairs...
# Batch processing complete.
# Rated 25 QA pairs
# Retained 23 pairs (threshold: 6.0)
# Average score: 7.8
# ⠇ Cleaning content from data/generated/cthulhu_500_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_500_qa_pairs_clean.json
# data/cleaned/cthulhu_181_qa_pairs_clean.json
# Doing 16 of 560 files
# Processing 4 batches of QA pairs...
# Batch processing complete.
# Rated 26 QA pairs
# Retained 26 pairs (threshold: 6.0)
# Average score: 8.4
# ⠇ Cleaning content from data/generated/cthulhu_181_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_181_qa_pairs_clean.json
# data/cleaned/cthulhu_201_qa_pairs_clean.json
# Doing 17 of 560 files
# Processing 4 batches of QA pairs...
# Batch processing complete.
# Rated 26 QA pairs
# Retained 25 pairs (threshold: 6.0)
# Average score: 8.0
# ⠏ Cleaning content from data/generated/cthulhu_201_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_201_qa_pairs_clean.json
# data/cleaned/cthulhu_57_qa_pairs_clean.json
# Doing 18 of 560 files
# Processing 4 batches of QA pairs...
# Batch processing complete.
# Rated 25 QA pairs
# Retained 24 pairs (threshold: 6.0)
# Average score: 7.9
# ⠴ Cleaning content from data/generated/cthulhu_57_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_57_qa_pairs_clean.json
# data/cleaned/cthulhu_247_qa_pairs_clean.json
# Doing 19 of 560 files
# Processing 4 batches of QA pairs...
# Batch processing complete.
# Rated 25 QA pairs
# Retained 25 pairs (threshold: 6.0)
# Average score: 8.3
# ⠋ Cleaning content from data/generated/cthulhu_247_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_247_qa_pairs_clean.json
# data/cleaned/cthulhu_331_qa_pairs_clean.json
# Doing 20 of 560 files
# Processing 3 batches of QA pairs...
# Batch processing complete.
# Rated 22 QA pairs
# Retained 22 pairs (threshold: 6.0)
# Average score: 8.1
# ⠋ Cleaning content from data/generated/cthulhu_331_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_331_qa_pairs_clean.json
# data/cleaned/cthulhu_271_qa_pairs_clean.json
# Doing 21 of 560 files
# Processing 4 batches of QA pairs...
# Batch processing complete.
# Rated 28 QA pairs
# Retained 20 pairs (threshold: 6.0)
# Average score: 5.9
# ⠹ Cleaning content from data/generated/cthulhu_271_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_271_qa_pairs_clean.json
# data/cleaned/cthulhu_161_qa_pairs_clean.json
# Doing 22 of 560 files
# Processing 4 batches of QA pairs...
# Batch processing complete.
# Rated 25 QA pairs
# Retained 25 pairs (threshold: 6.0)
# Average score: 8.2
# ⠹ Cleaning content from data/generated/cthulhu_161_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_161_qa_pairs_clean.json
# data/cleaned/cthulhu_47_qa_pairs_clean.json
# Doing 23 of 560 files
# Processing 4 batches of QA pairs...
# Batch processing complete.
# Rated 25 QA pairs
# Retained 24 pairs (threshold: 6.0)
# Average score: 8.0
# ⠸ Cleaning content from data/generated/cthulhu_47_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_47_qa_pairs_clean.json
# data/cleaned/cthulhu_199_qa_pairs_clean.json
# Doing 24 of 560 files
# Processing 4 batches of QA pairs...
# Batch processing complete.
# Rated 28 QA pairs
# Retained 28 pairs (threshold: 6.0)
# Average score: 8.2
# ⠇ Cleaning content from data/generated/cthulhu_199_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_199_qa_pairs_clean.json
# data/cleaned/cthulhu_203_qa_pairs_clean.json
# Doing 25 of 560 files
# Processing 3 batches of QA pairs...
# Batch processing complete.
# Rated 24 QA pairs
# Retained 24 pairs (threshold: 6.0)
# Average score: 8.2
# ⠧ Cleaning content from data/generated/cthulhu_203_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_203_qa_pairs_clean.json
# data/cleaned/cthulhu_536_qa_pairs_clean.json
# Doing 26 of 560 files
# Processing 5 batches of QA pairs...
# Batch processing complete.
# Rated 33 QA pairs
# Retained 12 pairs (threshold: 6.0)
# Average score: 3.9
# ⠏ Cleaning content from data/generated/cthulhu_536_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_536_qa_pairs_clean.json
# data/cleaned/cthulhu_125_qa_pairs_clean.json
# Doing 27 of 560 files
# Processing 3 batches of QA pairs...
# Batch processing complete.
# Rated 18 QA pairs
# Retained 18 pairs (threshold: 6.0)
# Average score: 8.1
# ⠸ Cleaning content from data/generated/cthulhu_125_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_125_qa_pairs_clean.json
# data/cleaned/cthulhu_546_qa_pairs_clean.json
# Doing 28 of 560 files
# Processing 4 batches of QA pairs...
# Batch processing complete.
# Rated 26 QA pairs
# Retained 8 pairs (threshold: 6.0)
# Average score: 3.2
# ⠙ Cleaning content from data/generated/cthulhu_546_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_546_qa_pairs_clean.json
# data/cleaned/cthulhu_325_qa_pairs_clean.json
# Doing 29 of 560 files
# Processing 3 batches of QA pairs...
# Batch processing complete.
# Rated 20 QA pairs
# Retained 18 pairs (threshold: 6.0)
# Average score: 7.6
# ⠇ Cleaning content from data/generated/cthulhu_325_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_325_qa_pairs_clean.json
# data/cleaned/cthulhu_264_qa_pairs_clean.json
# Doing 30 of 560 files
# Processing 4 batches of QA pairs...
# Batch processing complete.
# Rated 25 QA pairs
# Retained 25 pairs (threshold: 6.0)
# Average score: 8.0
# ⠹ Cleaning content from data/generated/cthulhu_264_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_264_qa_pairs_clean.json
# data/cleaned/cthulhu_132_qa_pairs_clean.json
# Doing 31 of 560 files
# Processing 3 batches of QA pairs...
# Batch processing complete.
# Rated 20 QA pairs
# Retained 19 pairs (threshold: 6.0)
# Average score: 7.8
# ⠏ Cleaning content from data/generated/cthulhu_132_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_132_qa_pairs_clean.json
# data/cleaned/cthulhu_360_qa_pairs_clean.json
# Doing 32 of 560 files
# Processing 4 batches of QA pairs...
# Batch processing complete.
# Rated 25 QA pairs
# Retained 25 pairs (threshold: 6.0)
# Average score: 8.4
# ⠸ Cleaning content from data/generated/cthulhu_360_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_360_qa_pairs_clean.json
# data/cleaned/cthulhu_370_qa_pairs_clean.json
# Doing 33 of 560 files
# Processing 4 batches of QA pairs...
# Batch processing complete.
# Rated 19 QA pairs
# Retained 19 pairs (threshold: 6.0)
# Average score: 8.4
# ⠏ Cleaning content from data/generated/cthulhu_370_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_370_qa_pairs_clean.json
# data/cleaned/cthulhu_505_qa_pairs_clean.json
# Doing 34 of 560 files
# Processing 3 batches of QA pairs...
# Batch processing complete.
# Rated 24 QA pairs
# Retained 23 pairs (threshold: 6.0)
# Average score: 8.1
# ⠦ Cleaning content from data/generated/cthulhu_505_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_505_qa_pairs_clean.json
# data/cleaned/cthulhu_527_qa_pairs_clean.json
# Doing 35 of 560 files
# Processing 4 batches of QA pairs...
# Batch processing complete.
# Rated 25 QA pairs
# Retained 24 pairs (threshold: 6.0)
# Average score: 8.0
# ⠇ Cleaning content from data/generated/cthulhu_527_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_527_qa_pairs_clean.json
# data/cleaned/cthulhu_469_qa_pairs_clean.json
# Doing 36 of 560 files
# Processing 3 batches of QA pairs...
# Batch processing complete.
# Rated 17 QA pairs
# Retained 16 pairs (threshold: 6.0)
# Average score: 8.1
# ⠼ Cleaning content from data/generated/cthulhu_469_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_469_qa_pairs_clean.json
# data/cleaned/cthulhu_224_qa_pairs_clean.json
# Doing 37 of 560 files
# Processing 4 batches of QA pairs...
# Batch processing complete.
# Rated 21 QA pairs
# Retained 21 pairs (threshold: 6.0)
# Average score: 7.9
# ⠇ Cleaning content from data/generated/cthulhu_224_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_224_qa_pairs_clean.json
# data/cleaned/cthulhu_122_qa_pairs_clean.json
# Doing 38 of 560 files
# Processing 3 batches of QA pairs...
# Batch processing complete.
# Rated 20 QA pairs
# Retained 20 pairs (threshold: 6.0)
# Average score: 8.0
# ⠸ Cleaning content from data/generated/cthulhu_122_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_122_qa_pairs_clean.json
# data/cleaned/cthulhu_206_qa_pairs_clean.json
# Doing 39 of 560 files
# Processing 3 batches of QA pairs...
# Batch processing complete.
# Rated 24 QA pairs
# Retained 24 pairs (threshold: 6.0)
# Average score: 8.4
# ⠏ Cleaning content from data/generated/cthulhu_206_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_206_qa_pairs_clean.json
# data/cleaned/cthulhu_159_qa_pairs_clean.json
# Doing 40 of 560 files
# Processing 3 batches of QA pairs...
# Batch processing complete.
# Rated 16 QA pairs
# Retained 16 pairs (threshold: 6.0)
# Average score: 8.3
# ⠋ Cleaning content from data/generated/cthulhu_159_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_159_qa_pairs_clean.json
# data/cleaned/cthulhu_404_qa_pairs_clean.json
# Doing 41 of 560 files
# Processing 3 batches of QA pairs...
# Batch processing complete.
# Rated 24 QA pairs
# Retained 24 pairs (threshold: 6.0)
# Average score: 8.0
# ⠙ Cleaning content from data/generated/cthulhu_404_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_404_qa_pairs_clean.json
# data/cleaned/cthulhu_128_qa_pairs_clean.json
# Doing 42 of 560 files
# Processing 2 batches of QA pairs...
# Batch processing complete.
# Rated 16 QA pairs
# Retained 16 pairs (threshold: 6.0)
# Average score: 8.1
# ⠏ Cleaning content from data/generated/cthulhu_128_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_128_qa_pairs_clean.json
# data/cleaned/cthulhu_143_qa_pairs_clean.json
# Doing 43 of 560 files
# Processing 3 batches of QA pairs...
# Batch processing complete.
# Rated 24 QA pairs
# Retained 24 pairs (threshold: 6.0)
# Average score: 8.5
# ⠋ Cleaning content from data/generated/cthulhu_143_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_143_qa_pairs_clean.json
# data/cleaned/cthulhu_150_qa_pairs_clean.json
# Doing 44 of 560 files
# Processing 3 batches of QA pairs...
# Batch processing complete.
# Rated 22 QA pairs
# Retained 22 pairs (threshold: 6.0)
# Average score: 8.2
# ⠸ Cleaning content from data/generated/cthulhu_150_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_150_qa_pairs_clean.json
# data/cleaned/cthulhu_554_qa_pairs_clean.json
# Doing 45 of 560 files
# Processing 3 batches of QA pairs...
# Batch processing complete.
# Rated 23 QA pairs
# Retained 1 pairs (threshold: 6.0)
# Average score: 1.4
# ⠏ Cleaning content from data/generated/cthulhu_554_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_554_qa_pairs_clean.json
# data/cleaned/cthulhu_39_qa_pairs_clean.json
# Doing 46 of 560 files
# Processing 3 batches of QA pairs...
# Batch processing complete.
# Rated 24 QA pairs
# Retained 24 pairs (threshold: 6.0)
# Average score: 8.4
# ⠦ Cleaning content from data/generated/cthulhu_39_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_39_qa_pairs_clean.json
# data/cleaned/cthulhu_451_qa_pairs_clean.json
# Doing 47 of 560 files
# Processing 3 batches of QA pairs...
# Batch processing complete.
# Rated 22 QA pairs
# Retained 22 pairs (threshold: 6.0)
# Average score: 8.1
# ⠸ Cleaning content from data/generated/cthulhu_451_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_451_qa_pairs_clean.json
# data/cleaned/cthulhu_388_qa_pairs_clean.json
# Doing 48 of 560 files
# Processing 3 batches of QA pairs...
# Batch processing complete.
# Rated 21 QA pairs
# Retained 21 pairs (threshold: 6.0)
# Average score: 8.2
# ⠏ Cleaning content from data/generated/cthulhu_388_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_388_qa_pairs_clean.json
# data/cleaned/cthulhu_105_qa_pairs_clean.json
# Doing 49 of 560 files
# Processing 3 batches of QA pairs...
# Batch processing complete.
# Rated 20 QA pairs
# Retained 20 pairs (threshold: 6.0)
# Average score: 8.2
# ⠹ Cleaning content from data/generated/cthulhu_105_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_105_qa_pairs_clean.json
# data/cleaned/cthulhu_381_qa_pairs_clean.json
# Doing 50 of 560 files
# Processing 3 batches of QA pairs...
# Batch processing complete.
# Rated 24 QA pairs
# Retained 24 pairs (threshold: 6.0)
# Average score: 8.2
# ⠋ Cleaning content from data/generated/cthulhu_381_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_381_qa_pairs_clean.json
# data/cleaned/cthulhu_555_qa_pairs_clean.json
# Doing 51 of 560 files
# Processing 4 batches of QA pairs...
# Batch processing complete.
# Rated 18 QA pairs
# Retained 18 pairs (threshold: 6.0)
# Average score: 8.1
# ⠸ Cleaning content from data/generated/cthulhu_555_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_555_qa_pairs_clean.json
# data/cleaned/cthulhu_383_qa_pairs_clean.json
# Doing 52 of 560 files
# Processing 4 batches of QA pairs...
# Batch processing complete.
# Rated 25 QA pairs
# Retained 25 pairs (threshold: 6.0)
# Average score: 8.2
# ⠇ Cleaning content from data/generated/cthulhu_383_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_383_qa_pairs_clean.json
# data/cleaned/cthulhu_191_qa_pairs_clean.json
# Doing 53 of 560 files
# Processing 3 batches of QA pairs...
# Batch processing complete.
# Rated 22 QA pairs
# Retained 22 pairs (threshold: 6.0)
# Average score: 8.2
# ⠇ Cleaning content from data/generated/cthulhu_191_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_191_qa_pairs_clean.json
# data/cleaned/cthulhu_543_qa_pairs_clean.json
# Doing 54 of 560 files
# Processing 4 batches of QA pairs...
# Batch processing complete.
# Rated 27 QA pairs
# Retained 16 pairs (threshold: 6.0)
# Average score: 5.4
# ⠙ Cleaning content from data/generated/cthulhu_543_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_543_qa_pairs_clean.json
# data/cleaned/cthulhu_297_qa_pairs_clean.json
# Doing 55 of 560 files
# Processing 3 batches of QA pairs...
# Batch processing complete.
# Rated 22 QA pairs
# Retained 22 pairs (threshold: 6.0)
# Average score: 8.4
# ⠙ Cleaning content from data/generated/cthulhu_297_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_297_qa_pairs_clean.json
# data/cleaned/cthulhu_245_qa_pairs_clean.json
# Doing 56 of 560 files
# Processing 4 batches of QA pairs...
# Batch processing complete.
# Rated 25 QA pairs
# Retained 25 pairs (threshold: 6.0)
# Average score: 8.2
# ⠼ Cleaning content from data/generated/cthulhu_245_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_245_qa_pairs_clean.json
# data/cleaned/cthulhu_456_qa_pairs_clean.json
# Doing 57 of 560 files
# Processing 2 batches of QA pairs...
# Batch processing complete.
# Rated 16 QA pairs
# Retained 16 pairs (threshold: 6.0)
# Average score: 8.1
# ⠴ Cleaning content from data/generated/cthulhu_456_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_456_qa_pairs_clean.json
# data/cleaned/cthulhu_174_qa_pairs_clean.json
# Doing 58 of 560 files
# Processing 3 batches of QA pairs...
# Batch processing complete.
# Rated 22 QA pairs
# Retained 22 pairs (threshold: 6.0)
# Average score: 8.0
# ⠸ Cleaning content from data/generated/cthulhu_174_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_174_qa_pairs_clean.json
# data/cleaned/cthulhu_167_qa_pairs_clean.json
# Doing 59 of 560 files
# Processing 3 batches of QA pairs...
# Batch processing complete.
# Rated 24 QA pairs
# Retained 23 pairs (threshold: 6.0)
# Average score: 8.0
# ⠴ Cleaning content from data/generated/cthulhu_167_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_167_qa_pairs_clean.json
# data/cleaned/cthulhu_347_qa_pairs_clean.json
# Doing 60 of 560 files
# Processing 4 batches of QA pairs...
# Batch processing complete.
# Rated 18 QA pairs
# Retained 18 pairs (threshold: 6.0)
# Average score: 7.8
# ⠹ Cleaning content from data/generated/cthulhu_347_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_347_qa_pairs_clean.json
# data/cleaned/cthulhu_311_qa_pairs_clean.json
# Doing 61 of 560 files
# Processing 3 batches of QA pairs...
# Batch processing complete.
# Rated 17 QA pairs
# Retained 16 pairs (threshold: 6.0)
# Average score: 7.5
# ⠼ Cleaning content from data/generated/cthulhu_311_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_311_qa_pairs_clean.json
# data/cleaned/cthulhu_209_qa_pairs_clean.json
# Doing 62 of 560 files
# Processing 3 batches of QA pairs...
# Batch processing complete.
# Rated 19 QA pairs
# Retained 18 pairs (threshold: 6.0)
# Average score: 7.8
# ⠋ Cleaning content from data/generated/cthulhu_209_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_209_qa_pairs_clean.json
# data/cleaned/cthulhu_142_qa_pairs_clean.json
# Doing 63 of 560 files
# Processing 3 batches of QA pairs...
# Batch processing complete.
# Rated 24 QA pairs
# Retained 24 pairs (threshold: 6.0)
# Average score: 8.3
# ⠋ Cleaning content from data/generated/cthulhu_142_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_142_qa_pairs_clean.json
# data/cleaned/cthulhu_200_qa_pairs_clean.json
# Doing 64 of 560 files
# Processing 3 batches of QA pairs...
# Batch processing complete.
# Rated 18 QA pairs
# Retained 16 pairs (threshold: 6.0)
# Average score: 7.6
# ⠙ Cleaning content from data/generated/cthulhu_200_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_200_qa_pairs_clean.json
# data/cleaned/cthulhu_87_qa_pairs_clean.json
# Doing 65 of 560 files
# Processing 4 batches of QA pairs...
# Batch processing complete.
# Rated 28 QA pairs
# Retained 26 pairs (threshold: 6.0)
# Average score: 7.8
# ⠸ Cleaning content from data/generated/cthulhu_87_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_87_qa_pairs_clean.json
# data/cleaned/cthulhu_24_qa_pairs_clean.json
# Doing 66 of 560 files
# Processing 3 batches of QA pairs...
# Batch processing complete.
# Rated 17 QA pairs
# Retained 7 pairs (threshold: 6.0)
# Average score: 5.1
# ⠇ Cleaning content from data/generated/cthulhu_24_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_24_qa_pairs_clean.json
# data/cleaned/cthulhu_538_qa_pairs_clean.json
# Doing 67 of 560 files
# Processing 4 batches of QA pairs...
# Batch processing complete.
# Rated 26 QA pairs
# Retained 8 pairs (threshold: 6.0)
# Average score: 3.2
# ⠦ Cleaning content from data/generated/cthulhu_538_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_538_qa_pairs_clean.json
# data/cleaned/cthulhu_213_qa_pairs_clean.json
# Doing 68 of 560 files
# Processing 3 batches of QA pairs...
# Batch processing complete.
# Rated 20 QA pairs
# Retained 20 pairs (threshold: 6.0)
# Average score: 7.9
# ⠧ Cleaning content from data/generated/cthulhu_213_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_213_qa_pairs_clean.json
# data/cleaned/cthulhu_529_qa_pairs_clean.json
# Doing 69 of 560 files
# Processing 4 batches of QA pairs...
# Batch processing complete.
# Rated 27 QA pairs
# Retained 16 pairs (threshold: 6.0)
# Average score: 5.2
# ⠙ Cleaning content from data/generated/cthulhu_529_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_529_qa_pairs_clean.json
# data/cleaned/cthulhu_223_qa_pairs_clean.json
# Doing 70 of 560 files
# Processing 4 batches of QA pairs...
# Batch processing complete.
# Rated 26 QA pairs
# Retained 26 pairs (threshold: 6.0)
# Average score: 8.0
# ⠸ Cleaning content from data/generated/cthulhu_223_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_223_qa_pairs_clean.json
# data/cleaned/cthulhu_551_qa_pairs_clean.json
# Doing 71 of 560 files
# Processing 3 batches of QA pairs...
# Batch processing complete.
# Rated 14 QA pairs
# Retained 5 pairs (threshold: 6.0)
# Average score: 4.1
# ⠴ Cleaning content from data/generated/cthulhu_551_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_551_qa_pairs_clean.json
# data/cleaned/cthulhu_225_qa_pairs_clean.json
# Doing 72 of 560 files
# Processing 3 batches of QA pairs...
# Batch processing complete.
# Rated 18 QA pairs
# Retained 18 pairs (threshold: 6.0)
# Average score: 8.2
# ⠸ Cleaning content from data/generated/cthulhu_225_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_225_qa_pairs_clean.json
# data/cleaned/cthulhu_425_qa_pairs_clean.json
# Doing 73 of 560 files
# Processing 3 batches of QA pairs...
# Batch processing complete.
# Rated 17 QA pairs
# Retained 17 pairs (threshold: 6.0)
# Average score: 8.2
# ⠙ Cleaning content from data/generated/cthulhu_425_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_425_qa_pairs_clean.json
# data/cleaned/cthulhu_1_qa_pairs_clean.json
# Doing 74 of 560 files
# Processing 3 batches of QA pairs...
# Batch processing complete.
# Rated 22 QA pairs
# Retained 21 pairs (threshold: 6.0)
# Average score: 8.4
# ⠏ Cleaning content from data/generated/cthulhu_1_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_1_qa_pairs_clean.json
# data/cleaned/cthulhu_507_qa_pairs_clean.json
# Doing 75 of 560 files
# Processing 3 batches of QA pairs...
# Batch processing complete.
# Rated 24 QA pairs
# Retained 23 pairs (threshold: 6.0)
# Average score: 8.0
# ⠏ Cleaning content from data/generated/cthulhu_507_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_507_qa_pairs_clean.json
# data/cleaned/cthulhu_265_qa_pairs_clean.json
# Doing 76 of 560 files
# Processing 3 batches of QA pairs...
# Batch processing complete.
# Rated 24 QA pairs
# Retained 24 pairs (threshold: 6.0)
# Average score: 8.4
# ⠴ Cleaning content from data/generated/cthulhu_265_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_265_qa_pairs_clean.json
# data/cleaned/cthulhu_492_qa_pairs_clean.json
# Doing 77 of 560 files
# Processing 4 batches of QA pairs...
# Batch processing complete.
# Rated 25 QA pairs
# Retained 24 pairs (threshold: 6.0)
# Average score: 8.1
# ⠹ Cleaning content from data/generated/cthulhu_492_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_492_qa_pairs_clean.json
# data/cleaned/cthulhu_28_qa_pairs_clean.json
# Doing 78 of 560 files
# Processing 4 batches of QA pairs...
# Batch processing complete.
# Rated 25 QA pairs
# Retained 25 pairs (threshold: 6.0)
# Average score: 8.2
# ⠹ Cleaning content from data/generated/cthulhu_28_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_28_qa_pairs_clean.json
# data/cleaned/cthulhu_315_qa_pairs_clean.json
# Doing 79 of 560 files
# Processing 4 batches of QA pairs...
# Batch processing complete.
# Rated 28 QA pairs
# Retained 28 pairs (threshold: 6.0)
# Average score: 8.3
# ⠙ Cleaning content from data/generated/cthulhu_315_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_315_qa_pairs_clean.json
# data/cleaned/cthulhu_376_qa_pairs_clean.json
# Doing 80 of 560 files
# Processing 4 batches of QA pairs...
# Batch processing complete.
# Rated 25 QA pairs
# Retained 25 pairs (threshold: 6.0)
# Average score: 8.4
# ⠧ Cleaning content from data/generated/cthulhu_376_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_376_qa_pairs_clean.json
# data/cleaned/cthulhu_525_qa_pairs_clean.json
# Doing 81 of 560 files
# Processing 3 batches of QA pairs...
# Batch processing complete.
# Rated 24 QA pairs
# Retained 8 pairs (threshold: 6.0)
# Average score: 3.5
# ⠼ Cleaning content from data/generated/cthulhu_525_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_525_qa_pairs_clean.json
# data/cleaned/cthulhu_136_qa_pairs_clean.json
# Doing 82 of 560 files
# Processing 3 batches of QA pairs...
# Batch processing complete.
# Rated 24 QA pairs
# Retained 24 pairs (threshold: 6.0)
# Average score: 8.5
# ⠇ Cleaning content from data/generated/cthulhu_136_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_136_qa_pairs_clean.json
# data/cleaned/cthulhu_250_qa_pairs_clean.json
# Doing 83 of 560 files
# Processing 4 batches of QA pairs...
# Batch processing complete.
# Rated 26 QA pairs
# Retained 24 pairs (threshold: 6.0)
# Average score: 7.9
# ⠋ Cleaning content from data/generated/cthulhu_250_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_250_qa_pairs_clean.json
# data/cleaned/cthulhu_34_qa_pairs_clean.json
# Doing 84 of 560 files
# Processing 3 batches of QA pairs...
# Batch processing complete.
# Rated 24 QA pairs
# Retained 21 pairs (threshold: 6.0)
# Average score: 8.0
# ⠼ Cleaning content from data/generated/cthulhu_34_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_34_qa_pairs_clean.json
# data/cleaned/cthulhu_380_qa_pairs_clean.json
# Doing 85 of 560 files
# Processing 3 batches of QA pairs...
# Batch processing complete.
# Rated 17 QA pairs
# Retained 17 pairs (threshold: 6.0)
# Average score: 8.3
# ⠧ Cleaning content from data/generated/cthulhu_380_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_380_qa_pairs_clean.json
# data/cleaned/cthulhu_165_qa_pairs_clean.json
# Doing 86 of 560 files
# Processing 3 batches of QA pairs...
# Batch processing complete.
# Rated 21 QA pairs
# Retained 21 pairs (threshold: 6.0)
# Average score: 8.0
# ⠴ Cleaning content from data/generated/cthulhu_165_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_165_qa_pairs_clean.json
# data/cleaned/cthulhu_506_qa_pairs_clean.json
# Doing 87 of 560 files
# Processing 3 batches of QA pairs...
# Batch processing complete.
# Rated 24 QA pairs
# Retained 23 pairs (threshold: 6.0)
# Average score: 7.9
# ⠹ Cleaning content from data/generated/cthulhu_506_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_506_qa_pairs_clean.json
# data/cleaned/cthulhu_63_qa_pairs_clean.json
# Doing 88 of 560 files
# Processing 3 batches of QA pairs...
# Batch processing complete.
# Rated 22 QA pairs
# Retained 22 pairs (threshold: 6.0)
# Average score: 8.5
# ⠧ Cleaning content from data/generated/cthulhu_63_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_63_qa_pairs_clean.json
# data/cleaned/cthulhu_162_qa_pairs_clean.json
# Doing 89 of 560 files
# Processing 3 batches of QA pairs...
# Batch processing complete.
# Rated 24 QA pairs
# Retained 24 pairs (threshold: 6.0)
# Average score: 8.2
# ⠸ Cleaning content from data/generated/cthulhu_162_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_162_qa_pairs_clean.json
# data/cleaned/cthulhu_258_qa_pairs_clean.json
# Doing 90 of 560 files
# Processing 4 batches of QA pairs...
# Batch processing complete.
# Rated 25 QA pairs
# Retained 24 pairs (threshold: 6.0)
# Average score: 8.0
# ⠦ Cleaning content from data/generated/cthulhu_258_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_258_qa_pairs_clean.json
# data/cleaned/cthulhu_458_qa_pairs_clean.json
# Doing 91 of 560 files
# Processing 3 batches of QA pairs...
# Batch processing complete.
# Rated 24 QA pairs
# Retained 24 pairs (threshold: 6.0)
# Average score: 8.0
# ⠦ Cleaning content from data/generated/cthulhu_458_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_458_qa_pairs_clean.json
# data/cleaned/cthulhu_131_qa_pairs_clean.json
# Doing 92 of 560 files
# Processing 4 batches of QA pairs...
# Batch processing complete.
# Rated 26 QA pairs
# Retained 26 pairs (threshold: 6.0)
# Average score: 8.3
# ⠋ Cleaning content from data/generated/cthulhu_131_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_131_qa_pairs_clean.json
# data/cleaned/cthulhu_512_qa_pairs_clean.json
# Doing 93 of 560 files
# Processing 3 batches of QA pairs...
# Batch processing complete.
# Rated 24 QA pairs
# Retained 22 pairs (threshold: 6.0)
# Average score: 7.6
# ⠴ Cleaning content from data/generated/cthulhu_512_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_512_qa_pairs_clean.json
# data/cleaned/cthulhu_493_qa_pairs_clean.json
# Doing 94 of 560 files
# Processing 3 batches of QA pairs...
# Batch processing complete.
# Rated 24 QA pairs
# Retained 20 pairs (threshold: 6.0)
# Average score: 7.0
# ⠏ Cleaning content from data/generated/cthulhu_493_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_493_qa_pairs_clean.json
# data/cleaned/cthulhu_447_qa_pairs_clean.json
# Doing 95 of 560 files
# Processing 4 batches of QA pairs...
# Batch processing complete.
# Rated 25 QA pairs
# Retained 25 pairs (threshold: 6.0)
# Average score: 8.0
# ⠋ Cleaning content from data/generated/cthulhu_447_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_447_qa_pairs_clean.json
# data/cleaned/cthulhu_40_qa_pairs_clean.json
# Doing 96 of 560 files
# Processing 3 batches of QA pairs...
# Batch processing complete.
# Rated 20 QA pairs
# Retained 12 pairs (threshold: 6.0)
# Average score: 6.2
# ⠇ Cleaning content from data/generated/cthulhu_40_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_40_qa_pairs_clean.json
# data/cleaned/cthulhu_346_qa_pairs_clean.json
# Doing 97 of 560 files
# Processing 4 batches of QA pairs...
# Batch processing complete.
# Rated 28 QA pairs
# Retained 28 pairs (threshold: 6.0)
# Average score: 8.2
# ⠙ Cleaning content from data/generated/cthulhu_346_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_346_qa_pairs_clean.json
# data/cleaned/cthulhu_534_qa_pairs_clean.json
# Doing 98 of 560 files
# Processing 3 batches of QA pairs...
# Batch processing complete.
# Rated 24 QA pairs
# Retained 8 pairs (threshold: 6.0)
# Average score: 3.6
# ⠧ Cleaning content from data/generated/cthulhu_534_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_534_qa_pairs_clean.json
# data/cleaned/cthulhu_464_qa_pairs_clean.json
# Doing 99 of 560 files
# Processing 2 batches of QA pairs...
# Batch processing complete.
# Rated 16 QA pairs
# Retained 15 pairs (threshold: 6.0)
# Average score: 7.9
# ⠹ Cleaning content from data/generated/cthulhu_464_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_464_qa_pairs_clean.json
# data/cleaned/cthulhu_363_qa_pairs_clean.json
# Doing 100 of 560 files
# Processing 3 batches of QA pairs...
# Batch processing complete.
# Rated 24 QA pairs
# Retained 24 pairs (threshold: 6.0)
# Average score: 8.2
# ⠼ Cleaning content from data/generated/cthulhu_363_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_363_qa_pairs_clean.json
# data/cleaned/cthulhu_479_qa_pairs_clean.json
# Doing 101 of 560 files
# Processing 3 batches of QA pairs...
# Batch processing complete.
# Rated 24 QA pairs
# Retained 24 pairs (threshold: 6.0)
# Average score: 8.3
# ⠋ Cleaning content from data/generated/cthulhu_479_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_479_qa_pairs_clean.json
# data/cleaned/cthulhu_179_qa_pairs_clean.json
# Doing 102 of 560 files
# Processing 3 batches of QA pairs...
# Batch processing complete.
# Rated 24 QA pairs
# Retained 22 pairs (threshold: 6.0)
# Average score: 7.9
# ⠼ Cleaning content from data/generated/cthulhu_179_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_179_qa_pairs_clean.json
# data/cleaned/cthulhu_498_qa_pairs_clean.json
# Doing 103 of 560 files
# Processing 3 batches of QA pairs...
# Batch processing complete.
# Rated 24 QA pairs
# Retained 24 pairs (threshold: 6.0)
# Average score: 8.4
# ⠇ Cleaning content from data/generated/cthulhu_498_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_498_qa_pairs_clean.json
# data/cleaned/cthulhu_521_qa_pairs_clean.json
# Doing 104 of 560 files
# Processing 4 batches of QA pairs...
# Batch processing complete.
# Rated 25 QA pairs
# Retained 25 pairs (threshold: 6.0)
# Average score: 8.1
# ⠹ Cleaning content from data/generated/cthulhu_521_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_521_qa_pairs_clean.json
# data/cleaned/cthulhu_306_qa_pairs_clean.json
# Doing 105 of 560 files
# Processing 3 batches of QA pairs...
# Batch processing complete.
# Rated 20 QA pairs
# Retained 16 pairs (threshold: 6.0)
# Average score: 7.0
# ⠸ Cleaning content from data/generated/cthulhu_306_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_306_qa_pairs_clean.json
# data/cleaned/cthulhu_541_qa_pairs_clean.json
# Doing 106 of 560 files
# Processing 3 batches of QA pairs...
# Batch processing complete.
# Rated 24 QA pairs
# Retained 11 pairs (threshold: 6.0)
# Average score: 4.5
# ⠸ Cleaning content from data/generated/cthulhu_541_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_541_qa_pairs_clean.json
# data/cleaned/cthulhu_304_qa_pairs_clean.json
# Doing 107 of 560 files
# Processing 3 batches of QA pairs...
# Batch processing complete.
# Rated 20 QA pairs
# Retained 20 pairs (threshold: 6.0)
# Average score: 8.3
# ⠴ Cleaning content from data/generated/cthulhu_304_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_304_qa_pairs_clean.json
# data/cleaned/cthulhu_462_qa_pairs_clean.json
# Doing 108 of 560 files
# Processing 3 batches of QA pairs...
# Batch processing complete.
# Rated 24 QA pairs
# Retained 23 pairs (threshold: 6.0)
# Average score: 8.0
# ⠴ Cleaning content from data/generated/cthulhu_462_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_462_qa_pairs_clean.json
# data/cleaned/cthulhu_387_qa_pairs_clean.json
# Doing 109 of 560 files
# Processing 3 batches of QA pairs...
# Batch processing complete.
# Rated 22 QA pairs
# Retained 22 pairs (threshold: 6.0)
# Average score: 8.0
# ⠹ Cleaning content from data/generated/cthulhu_387_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_387_qa_pairs_clean.json
# data/cleaned/cthulhu_58_qa_pairs_clean.json
# Doing 110 of 560 files
# Processing 3 batches of QA pairs...
# Batch processing complete.
# Rated 22 QA pairs
# Retained 22 pairs (threshold: 6.0)
# Average score: 8.1
# ⠇ Cleaning content from data/generated/cthulhu_58_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_58_qa_pairs_clean.json
# data/cleaned/cthulhu_194_qa_pairs_clean.json
# Doing 111 of 560 files
# Processing 4 batches of QA pairs...
# Batch processing complete.
# Rated 25 QA pairs
# Retained 25 pairs (threshold: 6.0)
# Average score: 8.3
# ⠴ Cleaning content from data/generated/cthulhu_194_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_194_qa_pairs_clean.json
# data/cleaned/cthulhu_289_qa_pairs_clean.json
# Doing 112 of 560 files
# Processing 3 batches of QA pairs...
# Batch processing complete.
# Rated 20 QA pairs
# Retained 20 pairs (threshold: 6.0)
# Average score: 8.1
# ⠏ Cleaning content from data/generated/cthulhu_289_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_289_qa_pairs_clean.json
# data/cleaned/cthulhu_427_qa_pairs_clean.json
# Doing 113 of 560 files
# Processing 4 batches of QA pairs...
# Batch processing complete.
# Rated 25 QA pairs
# Retained 25 pairs (threshold: 6.0)
# Average score: 8.1
# ⠧ Cleaning content from data/generated/cthulhu_427_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_427_qa_pairs_clean.json
# data/cleaned/cthulhu_276_qa_pairs_clean.json
# Doing 114 of 560 files
# Processing 2 batches of QA pairs...
# Batch processing complete.
# Rated 16 QA pairs
# Retained 16 pairs (threshold: 6.0)
# Average score: 8.3
# ⠦ Cleaning content from data/generated/cthulhu_276_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_276_qa_pairs_clean.json
# data/cleaned/cthulhu_410_qa_pairs_clean.json
# Doing 115 of 560 files
# Processing 3 batches of QA pairs...
# Batch processing complete.
# Rated 24 QA pairs
# Retained 24 pairs (threshold: 6.0)
# Average score: 8.4
# ⠙ Cleaning content from data/generated/cthulhu_410_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_410_qa_pairs_clean.json
# data/cleaned/cthulhu_497_qa_pairs_clean.json
# Doing 116 of 560 files
# Processing 4 batches of QA pairs...
# Batch processing complete.
# Rated 24 QA pairs
# Retained 24 pairs (threshold: 6.0)
# Average score: 8.2
# ⠸ Cleaning content from data/generated/cthulhu_497_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_497_qa_pairs_clean.json
# data/cleaned/cthulhu_29_qa_pairs_clean.json
# Doing 117 of 560 files
# Processing 4 batches of QA pairs...
# Batch processing complete.
# Rated 26 QA pairs
# Retained 23 pairs (threshold: 6.0)
# Average score: 7.8
# ⠏ Cleaning content from data/generated/cthulhu_29_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_29_qa_pairs_clean.json
# data/cleaned/cthulhu_488_qa_pairs_clean.json
# Doing 118 of 560 files
# Processing 3 batches of QA pairs...
# Batch processing complete.
# Rated 24 QA pairs
# Retained 23 pairs (threshold: 6.0)
# Average score: 7.9
# ⠇ Cleaning content from data/generated/cthulhu_488_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_488_qa_pairs_clean.json
# data/cleaned/cthulhu_524_qa_pairs_clean.json
# Doing 119 of 560 files
# Processing 3 batches of QA pairs...
# Batch processing complete.
# Rated 18 QA pairs
# Retained 18 pairs (threshold: 6.0)
# Average score: 8.3
# ⠹ Cleaning content from data/generated/cthulhu_524_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_524_qa_pairs_clean.json
# data/cleaned/cthulhu_155_qa_pairs_clean.json
# Doing 120 of 560 files
# Processing 3 batches of QA pairs...
# Batch processing complete.
# Rated 20 QA pairs
# Retained 20 pairs (threshold: 6.0)
# Average score: 8.3
# ⠙ Cleaning content from data/generated/cthulhu_155_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_155_qa_pairs_clean.json
# data/cleaned/cthulhu_344_qa_pairs_clean.json
# Doing 121 of 560 files
# Processing 3 batches of QA pairs...
# Batch processing complete.
# Rated 22 QA pairs
# Retained 22 pairs (threshold: 6.0)
# Average score: 8.1
# ⠦ Cleaning content from data/generated/cthulhu_344_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_344_qa_pairs_clean.json
# data/cleaned/cthulhu_550_qa_pairs_clean.json
# Doing 122 of 560 files
# Processing 3 batches of QA pairs...
# Batch processing complete.
# Rated 24 QA pairs
# Retained 8 pairs (threshold: 6.0)
# Average score: 3.5
# ⠏ Cleaning content from data/generated/cthulhu_550_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_550_qa_pairs_clean.json
# data/cleaned/cthulhu_441_qa_pairs_clean.json
# Doing 123 of 560 files
# Processing 3 batches of QA pairs...
# Batch processing complete.
# Rated 22 QA pairs
# Retained 22 pairs (threshold: 6.0)
# Average score: 8.1
# ⠋ Cleaning content from data/generated/cthulhu_441_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_441_qa_pairs_clean.json
# data/cleaned/cthulhu_362_qa_pairs_clean.json
# Doing 124 of 560 files
# Processing 3 batches of QA pairs...
# Batch processing complete.
# Rated 20 QA pairs
# Retained 20 pairs (threshold: 6.0)
# Average score: 8.0
# ⠏ Cleaning content from data/generated/cthulhu_362_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_362_qa_pairs_clean.json
# data/cleaned/cthulhu_480_qa_pairs_clean.json
# Doing 125 of 560 files
# Processing 4 batches of QA pairs...
# Batch processing complete.
# Rated 25 QA pairs
# Retained 25 pairs (threshold: 6.0)
# Average score: 8.2
# ⠇ Cleaning content from data/generated/cthulhu_480_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_480_qa_pairs_clean.json
# data/cleaned/cthulhu_149_qa_pairs_clean.json
# Doing 126 of 560 files
# Processing 3 batches of QA pairs...
# Batch processing complete.
# Rated 17 QA pairs
# Retained 17 pairs (threshold: 6.0)
# Average score: 8.1
# ⠏ Cleaning content from data/generated/cthulhu_149_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_149_qa_pairs_clean.json
# data/cleaned/cthulhu_198_qa_pairs_clean.json
# Doing 127 of 560 files
# Processing 3 batches of QA pairs...
# Batch processing complete.
# Rated 24 QA pairs
# Retained 24 pairs (threshold: 6.0)
# Average score: 8.1
# ⠸ Cleaning content from data/generated/cthulhu_198_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_198_qa_pairs_clean.json
# data/cleaned/cthulhu_449_qa_pairs_clean.json
# Doing 128 of 560 files
# Processing 3 batches of QA pairs...
# Batch processing complete.
# Rated 22 QA pairs
# Retained 14 pairs (threshold: 6.0)
# Average score: 5.6
# ⠇ Cleaning content from data/generated/cthulhu_449_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_449_qa_pairs_clean.json
# data/cleaned/cthulhu_364_qa_pairs_clean.json
# Doing 129 of 560 files
# Processing 3 batches of QA pairs...
# Batch processing complete.
# Rated 20 QA pairs
# Retained 19 pairs (threshold: 6.0)
# Average score: 8.1
# ⠸ Cleaning content from data/generated/cthulhu_364_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_364_qa_pairs_clean.json
# data/cleaned/cthulhu_391_qa_pairs_clean.json
# Doing 130 of 560 files
# Processing 4 batches of QA pairs...
# Batch processing complete.
# Rated 25 QA pairs
# Retained 22 pairs (threshold: 6.0)
# Average score: 7.5
# ⠧ Cleaning content from data/generated/cthulhu_391_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_391_qa_pairs_clean.json
# data/cleaned/cthulhu_342_qa_pairs_clean.json
# Doing 131 of 560 files
# Processing 4 batches of QA pairs...
# Batch processing complete.
# Rated 25 QA pairs
# Retained 25 pairs (threshold: 6.0)
# Average score: 8.2
# ⠴ Cleaning content from data/generated/cthulhu_342_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_342_qa_pairs_clean.json
# data/cleaned/cthulhu_270_qa_pairs_clean.json
# Doing 132 of 560 files
# Processing 3 batches of QA pairs...
# Batch processing complete.
# Rated 20 QA pairs
# Retained 19 pairs (threshold: 6.0)
# Average score: 8.0
# ⠴ Cleaning content from data/generated/cthulhu_270_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_270_qa_pairs_clean.json
# data/cleaned/cthulhu_77_qa_pairs_clean.json
# Doing 133 of 560 files
# Processing 4 batches of QA pairs...
# Batch processing complete.
# Rated 25 QA pairs
# Retained 25 pairs (threshold: 6.0)
# Average score: 8.3
# ⠹ Cleaning content from data/generated/cthulhu_77_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_77_qa_pairs_clean.json
# data/cleaned/cthulhu_234_qa_pairs_clean.json
# Doing 134 of 560 files
# Processing 4 batches of QA pairs...
# Batch processing complete.
# Rated 28 QA pairs
# Retained 23 pairs (threshold: 6.0)
# Average score: 7.2
# ⠴ Cleaning content from data/generated/cthulhu_234_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_234_qa_pairs_clean.json
# data/cleaned/cthulhu_352_qa_pairs_clean.json
# Doing 135 of 560 files
# Processing 3 batches of QA pairs...
# Batch processing complete.
# Rated 24 QA pairs
# Retained 23 pairs (threshold: 6.0)
# Average score: 7.9
# ⠹ Cleaning content from data/generated/cthulhu_352_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_352_qa_pairs_clean.json
# data/cleaned/cthulhu_240_qa_pairs_clean.json
# Doing 136 of 560 files
# Processing 3 batches of QA pairs...
# Batch processing complete.
# Rated 24 QA pairs
# Retained 24 pairs (threshold: 6.0)
# Average score: 8.0
# ⠧ Cleaning content from data/generated/cthulhu_240_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_240_qa_pairs_clean.json
# data/cleaned/cthulhu_76_qa_pairs_clean.json
# Doing 137 of 560 files
# Processing 3 batches of QA pairs...
# Batch processing complete.
# Rated 24 QA pairs
# Retained 23 pairs (threshold: 6.0)
# Average score: 7.8
# ⠦ Cleaning content from data/generated/cthulhu_76_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_76_qa_pairs_clean.json
# data/cleaned/cthulhu_30_qa_pairs_clean.json
# Doing 138 of 560 files
# Processing 3 batches of QA pairs...
# Batch processing complete.
# Rated 24 QA pairs
# Retained 24 pairs (threshold: 6.0)
# Average score: 8.2
# ⠼ Cleaning content from data/generated/cthulhu_30_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_30_qa_pairs_clean.json
# data/cleaned/cthulhu_408_qa_pairs_clean.json
# Doing 139 of 560 files
# Processing 4 batches of QA pairs...
# Batch processing complete.
# Rated 25 QA pairs
# Retained 24 pairs (threshold: 6.0)
# Average score: 7.7
# ⠏ Cleaning content from data/generated/cthulhu_408_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_408_qa_pairs_clean.json
# data/cleaned/cthulhu_237_qa_pairs_clean.json
# Doing 140 of 560 files
# Processing 3 batches of QA pairs...
# Batch processing complete.
# Rated 24 QA pairs
# Retained 21 pairs (threshold: 6.0)
# Average score: 7.4
# ⠧ Cleaning content from data/generated/cthulhu_237_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_237_qa_pairs_clean.json
# data/cleaned/cthulhu_241_qa_pairs_clean.json
# Doing 141 of 560 files
# Processing 3 batches of QA pairs...
# Batch processing complete.
# Rated 24 QA pairs
# Retained 24 pairs (threshold: 6.0)
# Average score: 8.1
# ⠇ Cleaning content from data/generated/cthulhu_241_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_241_qa_pairs_clean.json
# data/cleaned/cthulhu_13_qa_pairs_clean.json
# Doing 142 of 560 files
# Processing 3 batches of QA pairs...
# Batch processing complete.
# Rated 24 QA pairs
# Retained 24 pairs (threshold: 6.0)
# Average score: 8.4
# ⠼ Cleaning content from data/generated/cthulhu_13_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_13_qa_pairs_clean.json
# data/cleaned/cthulhu_414_qa_pairs_clean.json
# Doing 143 of 560 files
# Processing 4 batches of QA pairs...
# Batch processing complete.
# Rated 28 QA pairs
# Retained 28 pairs (threshold: 6.0)
# Average score: 8.1
# ⠋ Cleaning content from data/generated/cthulhu_414_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_414_qa_pairs_clean.json
# data/cleaned/cthulhu_335_qa_pairs_clean.json
# Doing 144 of 560 files
# Processing 4 batches of QA pairs...
# Batch processing complete.
# Rated 25 QA pairs
# Retained 25 pairs (threshold: 6.0)
# Average score: 8.2
# ⠴ Cleaning content from data/generated/cthulhu_335_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_335_qa_pairs_clean.json
# data/cleaned/cthulhu_322_qa_pairs_clean.json
# Doing 145 of 560 files
# Processing 2 batches of QA pairs...
# Batch processing complete.
# Rated 16 QA pairs
# Retained 16 pairs (threshold: 6.0)
# Average score: 8.2
# ⠸ Cleaning content from data/generated/cthulhu_322_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_322_qa_pairs_clean.json
# ...
# Processing 3 batches of QA pairs...
# Batch processing complete.
# Rated 24 QA pairs
# Retained 24 pairs (threshold: 6.0)
# Average score: 8.3
# ⠼ Cleaning content from data/generated/cthulhu_117_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_117_qa_pairs_clean.json
# data/cleaned/cthulhu_460_qa_pairs_clean.json
# Doing 515 of 560 files
# Processing 4 batches of QA pairs...
# Batch processing complete.
# Rated 28 QA pairs
# Retained 28 pairs (threshold: 6.0)
# Average score: 8.0
# ⠸ Cleaning content from data/generated/cthulhu_460_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_460_qa_pairs_clean.json
# data/cleaned/cthulhu_36_qa_pairs_clean.json
# Doing 516 of 560 files
# Processing 3 batches of QA pairs...
# Batch processing complete.
# Rated 24 QA pairs
# Retained 24 pairs (threshold: 6.0)
# Average score: 8.1
# ⠇ Cleaning content from data/generated/cthulhu_36_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_36_qa_pairs_clean.json
# data/cleaned/cthulhu_119_qa_pairs_clean.json
# Doing 517 of 560 files
# Processing 4 batches of QA pairs...
# Batch processing complete.
# Rated 25 QA pairs
# Retained 17 pairs (threshold: 6.0)
# Average score: 5.9
# ⠧ Cleaning content from data/generated/cthulhu_119_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_119_qa_pairs_clean.json
# data/cleaned/cthulhu_367_qa_pairs_clean.json
# Doing 518 of 560 files
# Processing 4 batches of QA pairs...
# Batch processing complete.
# Rated 25 QA pairs
# Retained 15 pairs (threshold: 6.0)
# Average score: 5.5
# ⠇ Cleaning content from data/generated/cthulhu_367_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_367_qa_pairs_clean.json
# data/cleaned/cthulhu_334_qa_pairs_clean.json
# Doing 519 of 560 files
# Processing 3 batches of QA pairs...
# Batch processing complete.
# Rated 20 QA pairs
# Retained 20 pairs (threshold: 6.0)
# Average score: 8.3
# ⠏ Cleaning content from data/generated/cthulhu_334_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_334_qa_pairs_clean.json
# data/cleaned/cthulhu_158_qa_pairs_clean.json
# Doing 520 of 560 files
# Processing 4 batches of QA pairs...
# Batch processing complete.
# Rated 28 QA pairs
# Retained 28 pairs (threshold: 6.0)
# Average score: 8.1
# ⠴ Cleaning content from data/generated/cthulhu_158_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_158_qa_pairs_clean.json
# data/cleaned/cthulhu_317_qa_pairs_clean.json
# Doing 521 of 560 files
# Processing 4 batches of QA pairs...
# Batch processing complete.
# Rated 26 QA pairs
# Retained 26 pairs (threshold: 6.0)
# Average score: 8.2
# ⠏ Cleaning content from data/generated/cthulhu_317_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_317_qa_pairs_clean.json
# data/cleaned/cthulhu_544_qa_pairs_clean.json
# Doing 522 of 560 files
# Processing 4 batches of QA pairs...
# Batch processing complete.
# Rated 27 QA pairs
# Retained 15 pairs (threshold: 6.0)
# Average score: 5.1
# ⠏ Cleaning content from data/generated/cthulhu_544_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_544_qa_pairs_clean.json
# data/cleaned/cthulhu_102_qa_pairs_clean.json
# Doing 523 of 560 files
# Processing 4 batches of QA pairs...
# Batch processing complete.
# Rated 26 QA pairs
# Retained 25 pairs (threshold: 6.0)
# Average score: 7.9
# ⠸ Cleaning content from data/generated/cthulhu_102_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_102_qa_pairs_clean.json
# data/cleaned/cthulhu_365_qa_pairs_clean.json
# Doing 524 of 560 files
# Processing 3 batches of QA pairs...
# Batch processing complete.
# Rated 17 QA pairs
# Retained 17 pairs (threshold: 6.0)
# Average score: 8.4
# ⠹ Cleaning content from data/generated/cthulhu_365_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_365_qa_pairs_clean.json
# data/cleaned/cthulhu_222_qa_pairs_clean.json
# Doing 525 of 560 files
# Processing 4 batches of QA pairs...
# Batch processing complete.
# Rated 25 QA pairs
# Retained 25 pairs (threshold: 6.0)
# Average score: 8.1
# ⠙ Cleaning content from data/generated/cthulhu_222_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_222_qa_pairs_clean.json
# data/cleaned/cthulhu_320_qa_pairs_clean.json
# Doing 526 of 560 files
# Processing 3 batches of QA pairs...
# Batch processing complete.
# Rated 22 QA pairs
# Retained 22 pairs (threshold: 6.0)
# Average score: 8.4
# ⠇ Cleaning content from data/generated/cthulhu_320_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_320_qa_pairs_clean.json
# data/cleaned/cthulhu_233_qa_pairs_clean.json
# Doing 527 of 560 files
# Processing 4 batches of QA pairs...
# Batch processing complete.
# Rated 26 QA pairs
# Retained 26 pairs (threshold: 6.0)
# Average score: 8.3
# ⠏ Cleaning content from data/generated/cthulhu_233_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_233_qa_pairs_clean.json
# data/cleaned/cthulhu_46_qa_pairs_clean.json
# Doing 528 of 560 files
# Processing 4 batches of QA pairs...
# Batch processing complete.
# Rated 28 QA pairs
# Retained 28 pairs (threshold: 6.0)
# Average score: 8.4
# ⠴ Cleaning content from data/generated/cthulhu_46_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_46_qa_pairs_clean.json
# data/cleaned/cthulhu_171_qa_pairs_clean.json
# Doing 529 of 560 files
# Processing 3 batches of QA pairs...
# Batch processing complete.
# Rated 24 QA pairs
# Retained 18 pairs (threshold: 6.0)
# Average score: 6.9
# ⠴ Cleaning content from data/generated/cthulhu_171_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_171_qa_pairs_clean.json
# data/cleaned/cthulhu_45_qa_pairs_clean.json
# Doing 530 of 560 files
# Processing 4 batches of QA pairs...
# Batch processing complete.
# Rated 25 QA pairs
# Retained 25 pairs (threshold: 6.0)
# Average score: 8.2
# ⠇ Cleaning content from data/generated/cthulhu_45_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_45_qa_pairs_clean.json
# data/cleaned/cthulhu_249_qa_pairs_clean.json
# Doing 531 of 560 files
# Processing 4 batches of QA pairs...
# Batch processing complete.
# Rated 28 QA pairs
# Retained 27 pairs (threshold: 6.0)
# Average score: 8.2
# ⠏ Cleaning content from data/generated/cthulhu_249_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_249_qa_pairs_clean.json
# data/cleaned/cthulhu_542_qa_pairs_clean.json
# Doing 532 of 560 files
# Processing 3 batches of QA pairs...
# Batch processing complete.
# Rated 23 QA pairs
# Retained 5 pairs (threshold: 6.0)
# Average score: 2.5
# ⠙ Cleaning content from data/generated/cthulhu_542_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_542_qa_pairs_clean.json
# data/cleaned/cthulhu_448_qa_pairs_clean.json
# Doing 533 of 560 files
# Processing 3 batches of QA pairs...
# Batch processing complete.
# Rated 20 QA pairs
# Retained 20 pairs (threshold: 6.0)
# Average score: 7.9
# ⠏ Cleaning content from data/generated/cthulhu_448_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_448_qa_pairs_clean.json
# data/cleaned/cthulhu_461_qa_pairs_clean.json
# Doing 534 of 560 files
# Processing 3 batches of QA pairs...
# Batch processing complete.
# Rated 24 QA pairs
# Retained 16 pairs (threshold: 6.0)
# Average score: 6.0
# ⠙ Cleaning content from data/generated/cthulhu_461_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_461_qa_pairs_clean.json
# data/cleaned/cthulhu_41_qa_pairs_clean.json
# Doing 535 of 560 files
# Processing 3 batches of QA pairs...
# Batch processing complete.
# Rated 24 QA pairs
# Retained 23 pairs (threshold: 6.0)
# Average score: 8.0
# ⠋ Cleaning content from data/generated/cthulhu_41_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_41_qa_pairs_clean.json
# data/cleaned/cthulhu_83_qa_pairs_clean.json
# Doing 536 of 560 files
# Processing 3 batches of QA pairs...
# Batch processing complete.
# Rated 24 QA pairs
# Retained 24 pairs (threshold: 6.0)
# Average score: 8.4
# ⠹ Cleaning content from data/generated/cthulhu_83_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_83_qa_pairs_clean.json
# data/cleaned/cthulhu_193_qa_pairs_clean.json
# Doing 537 of 560 files
# Processing 3 batches of QA pairs...
# Batch processing complete.
# Rated 24 QA pairs
# Retained 24 pairs (threshold: 6.0)
# Average score: 8.1
# ⠙ Cleaning content from data/generated/cthulhu_193_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_193_qa_pairs_clean.json
# data/cleaned/cthulhu_86_qa_pairs_clean.json
# Doing 538 of 560 files
# Processing 4 batches of QA pairs...
# Batch processing complete.
# Rated 28 QA pairs
# Retained 15 pairs (threshold: 6.0)
# Average score: 5.0
# ⠙ Cleaning content from data/generated/cthulhu_86_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_86_qa_pairs_clean.json
# data/cleaned/cthulhu_166_qa_pairs_clean.json
# Doing 539 of 560 files
# Processing 4 batches of QA pairs...
# Batch processing complete.
# Rated 25 QA pairs
# Retained 25 pairs (threshold: 6.0)
# Average score: 8.5
# ⠋ Cleaning content from data/generated/cthulhu_166_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_166_qa_pairs_clean.json
# data/cleaned/cthulhu_51_qa_pairs_clean.json
# Doing 540 of 560 files
# Processing 3 batches of QA pairs...
# Batch processing complete.
# Rated 22 QA pairs
# Retained 22 pairs (threshold: 6.0)
# Average score: 8.0
# ⠹ Cleaning content from data/generated/cthulhu_51_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_51_qa_pairs_clean.json
# data/cleaned/cthulhu_417_qa_pairs_clean.json
# Doing 541 of 560 files
# Processing 2 batches of QA pairs...
# Batch processing complete.
# Rated 16 QA pairs
# Retained 16 pairs (threshold: 6.0)
# Average score: 8.2
# ⠦ Cleaning content from data/generated/cthulhu_417_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_417_qa_pairs_clean.json
# data/cleaned/cthulhu_232_qa_pairs_clean.json
# Doing 542 of 560 files
# Processing 4 batches of QA pairs...
# Batch processing complete.
# Rated 28 QA pairs
# Retained 28 pairs (threshold: 6.0)
# Average score: 8.1
# ⠹ Cleaning content from data/generated/cthulhu_232_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_232_qa_pairs_clean.json
# data/cleaned/cthulhu_307_qa_pairs_clean.json
# Doing 543 of 560 files
# Processing 3 batches of QA pairs...
# Batch processing complete.
# Rated 24 QA pairs
# Retained 24 pairs (threshold: 6.0)
# Average score: 8.0
# ⠇ Cleaning content from data/generated/cthulhu_307_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_307_qa_pairs_clean.json
# data/cleaned/cthulhu_519_qa_pairs_clean.json
# Doing 544 of 560 files
# Processing 4 batches of QA pairs...
# Batch processing complete.
# Rated 26 QA pairs
# Retained 26 pairs (threshold: 6.0)
# Average score: 8.2
# ⠦ Cleaning content from data/generated/cthulhu_519_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_519_qa_pairs_clean.json
# data/cleaned/cthulhu_214_qa_pairs_clean.json
# Doing 545 of 560 files
# Processing 4 batches of QA pairs...
# Batch processing complete.
# Rated 25 QA pairs
# Retained 24 pairs (threshold: 6.0)
# Average score: 7.9
# ⠏ Cleaning content from data/generated/cthulhu_214_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_214_qa_pairs_clean.json
# data/cleaned/cthulhu_415_qa_pairs_clean.json
# Doing 546 of 560 files
# Processing 3 batches of QA pairs...
# Batch processing complete.
# Rated 22 QA pairs
# Retained 22 pairs (threshold: 6.0)
# Average score: 8.2
# ⠋ Cleaning content from data/generated/cthulhu_415_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_415_qa_pairs_clean.json
# data/cleaned/cthulhu_489_qa_pairs_clean.json
# Doing 547 of 560 files
# Processing 3 batches of QA pairs...
# Batch processing complete.
# Rated 18 QA pairs
# Retained 17 pairs (threshold: 6.0)
# Average score: 7.9
# ⠧ Cleaning content from data/generated/cthulhu_489_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_489_qa_pairs_clean.json
# data/cleaned/cthulhu_502_qa_pairs_clean.json
# Doing 548 of 560 files
# Processing 4 batches of QA pairs...
# Batch processing complete.
# Rated 29 QA pairs
# Retained 29 pairs (threshold: 6.0)
# Average score: 8.3
# ⠦ Cleaning content from data/generated/cthulhu_502_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_502_qa_pairs_clean.json
# data/cleaned/cthulhu_124_qa_pairs_clean.json
# Doing 549 of 560 files
# Processing 4 batches of QA pairs...
# Batch processing complete.
# Rated 25 QA pairs
# Retained 25 pairs (threshold: 6.0)
# Average score: 8.5
# ⠼ Cleaning content from data/generated/cthulhu_124_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_124_qa_pairs_clean.json
# data/cleaned/cthulhu_481_qa_pairs_clean.json
# Doing 550 of 560 files
# Processing 3 batches of QA pairs...
# Batch processing complete.
# Rated 22 QA pairs
# Retained 20 pairs (threshold: 6.0)
# Average score: 7.8
# ⠧ Cleaning content from data/generated/cthulhu_481_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_481_qa_pairs_clean.json
# data/cleaned/cthulhu_407_qa_pairs_clean.json
# Doing 551 of 560 files
# Processing 3 batches of QA pairs...
# Batch processing complete.
# Rated 24 QA pairs
# Retained 18 pairs (threshold: 6.0)
# Average score: 6.8
# ⠇ Cleaning content from data/generated/cthulhu_407_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_407_qa_pairs_clean.json
# data/cleaned/cthulhu_403_qa_pairs_clean.json
# Doing 552 of 560 files
# Processing 3 batches of QA pairs...
# Batch processing complete.
# Rated 24 QA pairs
# Retained 24 pairs (threshold: 6.0)
# Average score: 7.8
# ⠼ Cleaning content from data/generated/cthulhu_403_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_403_qa_pairs_clean.json
# data/cleaned/cthulhu_558_qa_pairs_clean.json
# Doing 553 of 560 files
# Processing 4 batches of QA pairs...
# Batch processing complete.
# Rated 25 QA pairs
# Retained 8 pairs (threshold: 6.0)
# Average score: 3.4
# ⠦ Cleaning content from data/generated/cthulhu_558_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_558_qa_pairs_clean.json
# data/cleaned/cthulhu_429_qa_pairs_clean.json
# Doing 554 of 560 files
# Processing 3 batches of QA pairs...
# Batch processing complete.
# Rated 24 QA pairs
# Retained 24 pairs (threshold: 6.0)
# Average score: 8.2
# ⠋ Cleaning content from data/generated/cthulhu_429_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_429_qa_pairs_clean.json
# data/cleaned/cthulhu_340_qa_pairs_clean.json
# Doing 555 of 560 files
# Processing 4 batches of QA pairs...
# Batch processing complete.
# Rated 24 QA pairs
# Retained 24 pairs (threshold: 6.0)
# Average score: 8.1
# ⠧ Cleaning content from data/generated/cthulhu_340_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_340_qa_pairs_clean.json
# data/cleaned/cthulhu_432_qa_pairs_clean.json
# Doing 556 of 560 files
# Processing 2 batches of QA pairs...
# Batch processing complete.
# Rated 16 QA pairs
# Retained 14 pairs (threshold: 6.0)
# Average score: 7.6
# ⠦ Cleaning content from data/generated/cthulhu_432_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_432_qa_pairs_clean.json
# data/cleaned/cthulhu_228_qa_pairs_clean.json
# Doing 557 of 560 files
# Processing 3 batches of QA pairs...
# Batch processing complete.
# Rated 24 QA pairs
# Retained 24 pairs (threshold: 6.0)
# Average score: 8.3
# ⠹ Cleaning content from data/generated/cthulhu_228_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_228_qa_pairs_clean.json
# data/cleaned/cthulhu_229_qa_pairs_clean.json
# Doing 558 of 560 files
# Processing 3 batches of QA pairs...
# Batch processing complete.
# Rated 24 QA pairs
# Retained 22 pairs (threshold: 6.0)
# Average score: 7.7
# ⠙ Cleaning content from data/generated/cthulhu_229_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_229_qa_pairs_clean.json
# data/cleaned/cthulhu_288_qa_pairs_clean.json
# Doing 559 of 560 files
# Processing 4 batches of QA pairs...
# Batch processing complete.
# Rated 25 QA pairs
# Retained 25 pairs (threshold: 6.0)
# Average score: 8.2
# ⠹ Cleaning content from data/generated/cthulhu_288_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_288_qa_pairs_clean.json
# data/cleaned/cthulhu_509_qa_pairs_clean.json
# Doing 560 of 560 files
# Processing 3 batches of QA pairs...
# Batch processing complete.
# Rated 24 QA pairs
# Retained 16 pairs (threshold: 6.0)
# Average score: 5.9
# ⠴ Cleaning content from data/generated/cthulhu_509_qa_pairs.json...
#  Cleaned content saved to data/cleaned/cthulhu_509_qa_pairs_clean.json

# %%
# store cleaned QA pair files in github so that we don't loose them when we
# close the notebook

! git config --global user.email "marco.pennacchiotti@gmail.com"
! git add data/cleaned
! git commit -m "added new cleaned qa pairs"
! git push origin main
# Out:
# [main 0334c2f] added new cleaned qa pairs
#  559 files changed, 233935 insertions(+)
#  create mode 100644 data/cleaned/cthulhu_0_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_100_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_101_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_102_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_103_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_104_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_105_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_106_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_107_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_108_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_109_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_10_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_110_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_111_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_112_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_113_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_114_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_115_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_116_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_117_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_118_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_119_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_11_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_120_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_121_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_122_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_123_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_124_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_125_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_126_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_127_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_128_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_129_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_12_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_130_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_131_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_132_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_133_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_134_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_135_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_136_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_137_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_138_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_139_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_13_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_140_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_141_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_142_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_143_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_144_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_145_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_146_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_147_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_148_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_149_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_14_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_150_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_151_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_152_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_153_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_154_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_155_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_156_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_157_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_158_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_159_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_15_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_160_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_161_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_162_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_163_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_164_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_165_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_166_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_167_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_168_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_169_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_16_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_170_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_171_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_172_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_173_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_174_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_175_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_176_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_177_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_178_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_179_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_17_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_180_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_181_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_182_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_183_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_184_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_185_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_186_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_187_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_188_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_189_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_18_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_190_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_191_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_192_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_193_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_194_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_195_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_196_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_197_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_198_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_199_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_19_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_1_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_200_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_201_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_202_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_203_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_204_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_205_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_206_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_207_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_208_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_209_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_20_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_210_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_211_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_212_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_213_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_214_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_215_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_216_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_217_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_218_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_219_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_21_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_220_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_221_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_222_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_223_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_224_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_225_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_226_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_227_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_228_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_229_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_22_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_230_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_231_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_232_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_233_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_234_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_235_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_236_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_237_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_238_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_239_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_23_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_240_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_241_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_242_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_243_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_244_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_245_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_246_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_247_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_248_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_249_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_24_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_250_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_251_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_252_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_253_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_254_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_255_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_256_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_257_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_258_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_259_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_25_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_260_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_261_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_262_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_263_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_264_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_265_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_266_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_267_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_268_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_269_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_26_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_270_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_271_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_272_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_273_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_274_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_275_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_276_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_277_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_278_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_279_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_27_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_280_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_281_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_282_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_283_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_284_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_285_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_286_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_287_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_288_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_289_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_28_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_290_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_291_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_292_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_293_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_294_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_295_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_296_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_297_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_298_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_299_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_29_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_2_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_300_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_301_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_302_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_303_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_304_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_305_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_306_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_307_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_308_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_309_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_30_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_310_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_311_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_312_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_313_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_314_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_315_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_316_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_317_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_318_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_319_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_31_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_320_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_321_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_322_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_323_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_324_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_325_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_326_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_327_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_328_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_329_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_32_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_330_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_331_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_332_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_333_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_334_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_335_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_336_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_337_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_338_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_339_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_33_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_340_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_341_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_342_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_343_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_344_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_345_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_346_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_347_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_348_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_349_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_34_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_350_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_351_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_352_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_353_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_354_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_355_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_356_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_357_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_358_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_359_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_35_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_360_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_361_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_362_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_363_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_364_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_365_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_366_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_367_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_369_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_36_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_370_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_371_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_372_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_373_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_374_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_375_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_376_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_377_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_378_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_379_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_37_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_380_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_381_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_382_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_383_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_384_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_385_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_386_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_387_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_388_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_389_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_38_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_390_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_391_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_392_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_393_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_394_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_395_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_396_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_397_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_398_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_399_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_39_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_3_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_400_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_401_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_402_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_403_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_404_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_405_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_406_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_407_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_408_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_409_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_40_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_410_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_411_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_412_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_413_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_414_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_415_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_416_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_417_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_418_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_419_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_41_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_420_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_421_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_422_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_423_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_424_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_425_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_426_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_427_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_428_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_429_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_42_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_430_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_431_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_432_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_433_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_434_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_435_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_436_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_437_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_438_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_439_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_43_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_440_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_441_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_442_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_443_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_444_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_445_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_446_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_447_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_448_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_449_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_44_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_450_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_451_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_452_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_453_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_454_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_455_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_456_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_457_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_458_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_459_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_45_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_460_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_461_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_462_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_463_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_464_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_465_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_466_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_467_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_468_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_469_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_46_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_470_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_471_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_472_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_473_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_474_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_475_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_476_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_477_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_478_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_479_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_47_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_480_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_481_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_482_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_483_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_484_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_485_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_486_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_487_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_488_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_489_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_48_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_490_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_491_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_492_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_493_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_494_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_495_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_496_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_497_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_498_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_499_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_49_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_4_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_500_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_501_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_502_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_503_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_504_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_505_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_506_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_507_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_508_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_509_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_50_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_510_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_511_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_512_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_513_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_514_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_515_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_516_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_517_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_518_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_519_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_51_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_520_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_521_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_522_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_523_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_524_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_525_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_526_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_527_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_528_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_529_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_52_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_530_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_531_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_532_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_533_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_534_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_535_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_536_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_537_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_538_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_539_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_53_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_540_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_541_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_542_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_543_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_544_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_545_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_546_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_547_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_548_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_549_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_54_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_550_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_551_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_552_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_553_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_554_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_555_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_556_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_557_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_558_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_559_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_55_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_56_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_57_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_58_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_59_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_5_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_60_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_61_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_62_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_63_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_64_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_65_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_66_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_67_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_68_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_69_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_6_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_70_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_71_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_72_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_73_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_74_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_75_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_76_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_77_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_78_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_79_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_7_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_80_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_81_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_82_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_83_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_84_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_85_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_86_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_87_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_88_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_89_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_8_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_90_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_91_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_92_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_93_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_94_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_95_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_96_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_97_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_98_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_99_qa_pairs_clean.json
#  create mode 100644 data/cleaned/cthulhu_9_qa_pairs_clean.json
# Enumerating objects: 565, done.
# Counting objects: 100% (565/565), done.
# Delta compression using up to 12 threads
# Compressing objects: 100% (563/563), done.
# Writing objects: 100% (563/563), 906.84 KiB | 3.16 MiB/s, done.
# Total 563 (delta 542), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (542/542), done.
# To github.com:ellolo/cthulhu_fine_tuning.git
#    d6414ed..0334c2f  main -> main

# %%
# check how many of the generated QA pairs have been retained after curation

import glob
import json

# %cd /content/cthulhu_fine_tuning/
clean_dir = "data/cleaned/*qa_pairs_clean.json"

fnames = glob.glob(clean_dir)
total_pairs = 0
retained_pairs = 0
bad_count = 0
for fname in fnames:
  with open(fname, 'r', encoding='utf-8') as f:
    try:
      data = json.load(f)
      metrics = data["metrics"]
      total_pairs += metrics["total"]
      retained_pairs += metrics["filtered"]
    except:
      print(f"Skipping file: {fname} (bad json).")
      bad_count += 1

print(f"Retained {retained_pairs} QA pairs of total {total_pairs} ({retained_pairs / total_pairs})")
print(f"{bad_count} file of total {len(fnames)} where skipped (bad json).")
# Out:
# /content/cthulhu_fine_tuning
# Retained 11930 QA pairs of total 13100 (0.9106870229007633)
# 0 file of total 559 where skipped (bad json).

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# # Utils to check GPU status

# %%
!  nvidia-smi
# Out:
# Fri May 16 10:42:14 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A100-SXM4-40GB          Off |   00000000:00:04.0 Off |                    0 |
# | N/A   41C    P0             58W /  400W |     423MiB /  40960MiB |      0%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# +-----------------------------------------------------------------------------------------+

# %%
# check pids running on gpu
! sudo fuser -v /dev/nvidia*
# Out:
#                      USER        PID ACCESS COMMAND
# /dev/nvidia0:        root        717 F...m python3
# /dev/nvidiactl:      root        717 F...m python3
# /dev/nvidia-uvm:     root        717 F...m python3

# %%
# kill some pids
! kill -9 9597

# %% [markdown]
# # Old code (deprecated)

# %% [markdown]
# This is old code to install dependencies if one wanto to use the unsloth wrapper (see: )

# %%
# install dependencies

# %%capture
import os
if "COLAB_" not in "".join(os.environ.keys()):
    # !pip install unsloth vllm
    # !pip install synthetic-data-kit==0.0.3
else:
    # [NOTE] Do the below ONLY in Colab! Use [[pip install unsloth vllm]]
    # !pip install --no-deps unsloth vllm
    # !pip install synthetic-data-kit==0.0.3

# %%
# %%capture
import os
if "COLAB_" not in "".join(os.environ.keys()):
    # !pip install unsloth vllm
else:
    # !pip install --no-deps unsloth vllm
    # [NOTE] Do the below ONLY in Colab! Use [[pip install unsloth vllm]]
    # Skip restarting message in Colab
    import sys, re, requests; modules = list(sys.modules.keys())
    for x in modules: sys.modules.pop(x) if "PIL" in x or "google" in x else None
    # !pip install --no-deps bitsandbytes accelerate xformers==0.0.29.post3 peft "trl==0.15.2" triton cut_cross_entropy unsloth_zoo
    # !pip install sentencepiece protobuf "datasets>=3.4.1" huggingface_hub hf_transfer

    # vLLM requirements - vLLM breaks Colab due to reinstalling numpy
    f = requests.get("https://raw.githubusercontent.com/vllm-project/vllm/refs/heads/main/requirements/common.txt").content
    with open("vllm_requirements.txt", "wb") as file:
        file.write(re.sub(rb"(transformers|numpy|xformers)[^\n]{1,}\n", b"", f))
    # !pip install -r vllm_requirements.txt

# %% [markdown]
# Launching the vllm server using unsloth, as in the cell below,  did not work. The server of the llm started hanging after 3 documents.
# This is why we instead launch the server manually using `vllm serve unsloth/Llama-3.2-3B-Instruct`.

# %%
# START AND SERVE LLM MODEL
#
# initialize model that will generate the dataset and serve it on port 8000
# Specifically:
#   - initialize HF tokenizer for the specific model
#   - Sets max_seq_length: user-specified length of input sequence (context +
#     generated tokens) if mem allows
#   - Sets max_num_seqs (i.e. prompts that can be passed in a single inference
#     call) based on avail mem.
#   - Load vllm model bitsandbytes weights quantization
#     (https://docs.vllm.ai/en/latest/,
#     https://docs.vllm.ai/en/latest/api/vllm/vllm.engine.llm_engine.html)
#   - serve vllm model on localhost:8000 as a subprocess

from unsloth.dataprep import SyntheticDataKit

generator = SyntheticDataKit.from_pretrained(
    # Choose any model from https://huggingface.co/unsloth
   #model_name = "unsloth/Llama-3.3-70B-Instruct",
    model_name = "unsloth/Llama-3.2-3B-Instruct",
    max_seq_length = 2048, # Longer sequence lengths will be slower!
    gpu_memory_utilization = 0.85,
)

# %%
# CONFIGURE QUESTION GENERATION
#
# Sets the parameters that will be used for generating QA pairs using the
# Meta Toolkit.
# Parameters are:
#  - temperature
#  - top_p
#  - chunk_size:            size of text chunks for processing (i.e. how big are
#                           the chunks in which each document will be split)
#  - overlap:               overlap (num tokens) between chunks to maintain
#                           context
#  - max_generation_tokens: max number of tokens that will be generated by the
#                           model when generating a single question
#  - num_pairs:             default number of QA pairs to generate for each
#                           chunk
#
# Note that the chunk_size parameter of the Meta toolkit is set automatically to
# max_seq_length - max_generation_tokens*2
# chunk_size is basically the size of the input layer.
#
# All the parameters above are then written to the config file of the  Meta
# toolkit (synthetic_data_kit_config.yaml).
#
# See here for full config documentation of the Meta Toolkit:
# https://github.com/meta-llama/synthetic-data-kit/blob/main/synthetic_data_kit/config.yaml
generator.prepare_qa_generation(
    output_folder = "data", # Output location of synthetic data
    temperature = 0.7, # Higher temp makes more diverse datases
    top_p = 0.95,
    overlap = 64, # Overlap portion during chunking
    max_generation_tokens = 512, # Can increase for longer QA pairs
)

# %%
# !synthetic-data-kit system-check

# %%
while True:
    line = generator.vllm_process.stdout.readline()
    if not line:
        break
    print(line.rstrip(), flush=True)

# %%
# PREPARE TEXT INTO CHUNKS
#
# parse pdf and store into text file into data/output directory.
print("Extracting pdf...")
# !synthetic-data-kit \
    -c synthetic_data_kit_config.yaml \
    ingest data/pdf/cthulhu.pdf

# Tokenize the document using appropriate tokenizer, splits the full token
# sequence into chunks of length chunk_size tokens, and stores the corresponding
# textual chunks into output directory
print("Tokenizing and chunking...")
filenames = generator.chunk_data("data/output/cthulhu.txt")
print(len(filenames), filenames[:3])
# Out:
# Extracting pdf...
# ⠏ Processing data/pdf/cthulhu.pdf...
#  Text successfully extracted to data/output/cthulhu.txt
# Tokenizing and chunking...
# 560 ['data/output/cthulhu_0.txt', 'data/output/cthulhu_1.txt', 'data/output/cthulhu_2.txt']

# %%
# GENERATE QA PAIRS
#
# The output is sotired into data/generated
#
# Parameters:
#  --num-pairs: number of generations per chunk (e.g. num of QA pairs)
#  --type:      type of generation. Can be:
#               qa: QA pairs
#               cot: chain of thoughts
#
# QA are generated as follows, for each chunk:
#   - ask llm to generate a 3-5 sentence summary of the chunk, using the prompt
#     stored in the config file: https://github.com/meta-llama/synthetic-data-kit/blob/main/configs/config.yaml)
#     temperature for this task is set to 0.1
#   - sub-chunks each chunk into smaller chunks
#   - ask to generate 25 QA pairs for each chunk. Specifically, for each
#     sub-chunk: ask llm to generate 25/num_subchunks QA pairs using QA prompt
#     stored in the config file: https://github.com/meta-llama/synthetic-data-kit/blob/main/configs/config.yaml)
#
# Look here for more details:
# https://github.com/meta-llama/synthetic-data-kit/blob/main/synthetic_data_kit/generators/qa_generator.py
import glob
import os

out_dir = "data/output"
gen_dir = "data/generated"

# get list of files for which QA pairs have been already generated
generated_files = glob.glob(f"{gen_dir}/*pairs.json")
if generated_files:
  print(generated_files)
  base_name = generated_files[0].split("/")[-1]
  base_name = "_".join(base_name.split("_")[0:-3])
  completed_files = [
      f"{out_dir}/{base_name}_{fname.split('_')[-3]}.txt" for fname in generated_files
      ]
  print(f"QA pairs already generated for {len(completed_files)} files")

  # get list of output files
  filenames = sorted(glob.glob(f"{out_dir}/*_[0-9]*.txt"), key=os.path.getmtime)
  filenames_to_do = list(set(filenames) - set(completed_files))
  print(f"Need to generate for {len(filenames_to_do)} files")
else:
  filenames_to_do = filenames
  print(f"Need to generate for {len(filenames_to_do)} files")
# Out:
# ['data/generated/cthulhu_1_qa_pairs.json']
# QA pairs already generated for 1 files
# Need to generate for 559 files

# %%
import time
for fname in filenames_to_do[:30]:
    # !synthetic-data-kit \
        -c synthetic_data_kit_config.yaml \
        create {fname} \
        --num-pairs 25 \
        --type "qa"
    time.sleep(5) # Sleep some time to leave some room for processing
# Out:
# Processing 5 chunks to generate QA pairs...
# Batch processing complete.
# Generated 25 QA pairs total
# Saving result to data/generated/cthulhu_160_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_160_qa_pairs.json
# ⠸ Generating qa content from data/output/cthulhu_160.txt...
#  Content saved to data/generated/cthulhu_160_qa_pairs.json
# Processing 6 chunks to generate QA pairs...
# Batch processing complete.
# Generated 24 QA pairs total
# Saving result to data/generated/cthulhu_44_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_44_qa_pairs.json
# ⠋ Generating qa content from data/output/cthulhu_44.txt...
#  Content saved to data/generated/cthulhu_44_qa_pairs.json
# Processing 7 chunks to generate QA pairs...
# Batch processing complete.
# Generated 0 QA pairs total
# Saving result to data/generated/cthulhu_251_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json
# Successfully wrote result to data/generated/cthulhu_251_qa_pairs.json
# ⠸ Generating qa content from data/output/cthulhu_251.txt...
#  Content saved to data/generated/cthulhu_251_qa_pairs.json
# L Error: VLLM server not available at http://localhost:8000/v1
# Please start the VLLM server with:
# vllm serve unsloth/Llama-3.2-3B-Instruct
# L Error: VLLM server not available at http://localhost:8000/v1
# Please start the VLLM server with:
# vllm serve unsloth/Llama-3.2-3B-Instruct
# L Error: VLLM server not available at http://localhost:8000/v1
# Please start the VLLM server with:
# vllm serve unsloth/Llama-3.2-3B-Instruct
# L Error: VLLM server not available at http://localhost:8000/v1
# Please start the VLLM server with:
# vllm serve unsloth/Llama-3.2-3B-Instruct
# L Error: VLLM server not available at http://localhost:8000/v1
# Please start the VLLM server with:
# vllm serve unsloth/Llama-3.2-3B-Instruct
# L Error: VLLM server not available at http://localhost:8000/v1
# Please start the VLLM server with:
# vllm serve unsloth/Llama-3.2-3B-Instruct
# L Error: VLLM server not available at http://localhost:8000/v1
# Please start the VLLM server with:
# vllm serve unsloth/Llama-3.2-3B-Instruct
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-52-d19ece1c0fa8> in <cell line: 0>()
#       2 for fname in filenames_to_do[:30]:
#       3     get_ipython().system('synthetic-data-kit          -c synthetic_data_kit_config.yaml          create {fname}          --num-pairs 25          --type "qa"')
# ----> 4     time.sleep(5) # Sleep some time to leave some room for processing
#       5
#       6
#
# KeyboardInterrupt:

# %% [markdown]
# This is old code used to tunnel the vllm server endpoints (which are running on localhost:8000) to a web page in the internet. This is done using localx-colab.
#
# This was used to check the status, metrics, etc of the vllm server, in an attempt to debug it. However thee is not endpoint for debug messages, therefore ended up not using this,

# %%
# !pip install loclx-colab

# SETUP TUNNELING
import loclx_colab.loclx as lx
port = 8000 # The service port that you want to expose
access_token = 'CQFAU5poxrD8CJxVcNBf9Xy1FIPoT2wGkUip4H3Z' # Your LocalXpose token here
url = lx.http_tunnel_start(port, access_token)
print(f"Your service is exposed to this URL: https://{url}")
print(f"List models: https://{url}/v1/models")
print(f"Metrics: https://{url}/metrics")

# %%
lx.login(access_token)
lx.http_tunnel_status()
